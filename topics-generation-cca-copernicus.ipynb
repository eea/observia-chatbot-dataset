# %%
path = "data-download/Copernicus"

# %%
import os
import json

def process_json_files(directory, callback):
    # Ensure the directory exists
    if not os.path.isdir(directory):
        raise ValueError(f"The directory '{directory}' does not exist or is not a directory.")
    
    # Iterate through all files in the directory
    for filename in os.listdir(directory):
        if filename.endswith(".json"):  # Filter for JSON files
            filepath = os.path.join(directory, filename)
            if os.path.isfile(filepath):  # Ensure it's a file
                # print(f"Processing JSON file: {filename}")
                try:
                    with open(filepath, 'r') as file:
                        callback(file)
                except Exception as e:
                    print(f"Error processing {filename}: {e}")

# %%
documents = []

def read_content(fd):
    data = json.load(fd)
    documents.append(data['fields'].get('content', ''))

process_json_files(path, read_content)
len(documents)
# Out:
# 43744

# %%
from sentence_transformers import SentenceTransformer

# Pre-calculate embeddings
embedding_model = SentenceTransformer("all-MiniLM-L6-v2")
embeddings = embedding_model.encode(documents, show_progress_bar=True)
# Out:
# Batches:   0%|          | 0/1367 [00:00<?, ?it/s]

# %%
from bertopic import BERTopic
from hdbscan import HDBSCAN
from bertopic.representation import KeyBERTInspired
from sklearn.cluster import KMeans
import os
import openai

client = openai.OpenAI(
  api_key="",
  base_url="https://api.together.xyz/v1",
)

# cluster_model = KMeans(n_clusters=20)
cluster_model = HDBSCAN(min_cluster_size=20, metric='euclidean', cluster_selection_method='eom', prediction_data=True)

representation_model = KeyBERTInspired()
topic_model = BERTopic(representation_model=representation_model, embedding_model=embedding_model, hdbscan_model=cluster_model)
topics, probs = topic_model.fit_transform(documents, embeddings)
# Out:
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)

# %%
for topic_id in topic_model.topic_representations_.keys():
    topics_data = topic_model.topic_representations_[topic_id]
    topic = ", ".join([x[0] for x in topics_data])
    print(topic)
# Out:
# copernicus, sentinel, monitoring, cookies, climate, monitor, earth, european, slovenian, temperature
# koje, praćenje, poskytuje, spremljanje, oceana, upravljanje, oceanu, oceánů, oceánu, razvoja
# замърсяването, център, състоянието, замърсяване, свързани, вълни, със, например, променливи, морския
# taħt, baħar, oħra, għan, bħal, bħala, għal, jistgħu, għall, tagħna
# επιφάνειας, θερμοκρασίας, περιοχές, περιπτώσεις, επιφάνεια, παρατηρήσεις, διαχείριση, στις, θερμοκρασία, πληροφορίες
# copernicus, volcano, eruption, sentinel, earth, eu, events, observation, slovenian, european
# och, europæiske, europeiska, det, indikatorer, bæredygtig, kan, tjenester, eller, så
# wildfires, fires, wildfire, emissions, arctic, siberia, fire, atmosphere, forecasts, weather
# óceánok, óceán, óceáni, szolgáltatások, szolgáltatás, kopernikusz, személyes, európai, szolgálat, erőforrások
# salinity, dataset, sea, wekeo, data, range, elevation, jupyterhub, map, measure
# antarctic, arctic, antarctica, climate, seas, ice, sea, february, greenland, 2022
# atmospheric, pollution, ozone, atmosphere, emissions, aerosol, pollutants, weather, monitoring, emission
# wpływ, usługi, usług, działania, zarządzania, wykorzystywane, użytkownika, przybrzeżnych, że, ze
# ookeanide, ookeani, ookean, temperatuuri, kliimamuutuste, aaltojen, lainete, süsiniku, mõju, ovat
# kliknite, croatian, finnish, swedish, slovenian, estonian, czech, slovak, politiky, koje
# ozeane, ozeans, ozean, auswirkungen, europäischen, meeresoberfläche, entwicklung, beobachtungen, zu, ressourcen
# european, copernicus, gdpr, estonian, slovenian, swedish, lithuanian, latvian, bulgarian, mailerlite
# copernicus, eu, space, galileo, euspa, earth, european, future, horizon, technologies
# consultivo, trabalhamos, estratégia, estrategia, serviços, serviço, consultatif, científico, trabajamos, servicio
# europese, ecosystemen, oceanen, persoonlijke, verschillende, monitoren, indicatoren, ontwikkeling, kustgebieden, belangrijke
# océanos, oceanos, oceanului, océano, oceano, oceanul, oceani, carbonio, oceaniche, carbono
# copernicus, climate, ecmwf, cop26, cop28, atmosphere, forecasts, weather, c3s, unfccc
# lietotāju, produktai, informacijos, įsipareigojimai, produkti, licencija, produktus, veikla, monitoringa, marine
# copernicuse, marine, käyttötapaukset, euroopa, euroopan, meripalvelun, jotta, käyttää, käytetään, tietojen
# copernicus, ocean, coastal, volcano, sentinel, marine, eruption, portugal, eusso, mount
# oceanos, océanos, océano, oceano, estrategia, estratégia, servicios, servicio, serviços, usuarios
# precipitation, rainfall, humidity, moisture, hydrological, balkans, temperature, scandinavia, europe, soil
# copernicus, cookies, preferences, slovenian, estonian, français, lithuanian, greek, accept, croatian
# copernicus_sentinel_license, sentinel, copernicus, copernicus_land_monitoring_service_data_policy, copernicus_general_license, sentinels, eumetsat_copernicus_data_licence, copernicus_dem_instance_cop, copernicus_marine_service_product_license, copernicus_ecmwf_license
# océanos, oceanos, océano, oceano, oceanul, oceani, oceanografia, estado, como, oceanelor
# πλαστική, πολιτικές, greek, πληροφορίες, ποιους, γαλάζιες, κλείστε, απαιτήσεις, χρήστες, αγορές
# ookeanide, ookeani, ookean, estonian, finnish, sektoriui, swedish, lithuanian, latvian, kasutusjuhtumid
# sentinel, satellites, satellite, esa, radar, volcano, eruption, imagery, monitor, mount
# massimili, 3dvarbio, biogeoquímicos, assimilation, 3dvar, cmems, bio, bgc, modelo, 1016
# център, коперник, замърсяване, морски, български, затвори, за, заинтересовани, изисквания, морските
# oceano, modelos, modelo, como, wave2nemo, projeto, observações, modello, resultado, olas
# precipitation, snowfall, snow, rain, forecasting, runoff, clouds, evaporation, ensemble, accumulation
# okeāna, okeānā, ekosistēmas, piekrastes, ilgtspējīgas, sasilšana, izraisa, okeānu, lietošanas, akvakultūras
# gdpr, analytics, privacy, cookies, mailerlite, email, european, newsletter, twitter, https
# baħar, għall, għal, agħlaq, sħana, naħdmu, tagħna, għarfien, aħbarijiet, oċeani
# gdpr, mailerlite, copernicus, cookies, email, newsletter, european, privacy, twitter, slovenian
# gdpr, analytics, privacy, cookies, monitor, cookie, anonymised, email, https, mailerlite
# copernicus, climate, volcano, eruption, emissions, european, co2, portugal, indonesia, events
# hydrological, climate, drought, forecasts, meteorological, forecast, rainfall, floods, flooding, hydropower
# ozone, stratosphere, antarctic, atmosphere, stratospheric, antarctica, ultraviolet, sun, arctic, ecmwf
# wave, wavewatch, waveflow, wave2nemo, mywave, projektu, projekta, modeļa, modela, modelio
# microplastics, microplastic, plastics, pollution, oceans, debris, plastic, sea, marine, ocean
# pieeja, lithuanian, informuotumas, piesārņojums, latvian, plastmasas, skaidrotāji, lietotāju, aiškintojai, politika
# mercator, volcano, repository, eruption, portugal, slovenian, swedish, eusso, laki, portuguese
# climate, c3s, datasets, ecmwf, data, europa, ecv, software, catalogue, eqc
# humidity, climate, precipitation, moisture, annual, soil, copernicus, temperature, 2024, 2021
# aquaculture, fisheries, fishery, fish, shellfish, fishing, sea, jellyfish, aquatic, marine
# co2, co₂, emissions, methane, greenhouse, carbon, atmosphere, gases, atmospheric, dioxide
# oceanography, oceanpredict, ocean, seas, coastal, biogeosciences, biogeochemical, scientist, sciences, prediction
# downloading, downloads, dataset, download, datasets, customise, package, file, packaged, redownload
# salinity, global_analysis_forecast_bio_001_028, global_analysis_forecast_phy_001_024, lambda, pcoms, projekta, projektu, projekt, 06o, sāļuma
# χρήστες, χρησιμοποιούνται, περιπτώσεις, δείκτες, υπηρεσίας, πολιτικών, δραστηριότητες, δεσμεύσεις, στις, έως
# copernicus, oceanpredict, ocean, marine, forecasting, cmems_eu, cmems, upcoming, 2024, symposium
# plastföroreningar, swedish, och, tillvägagångssätt, plastikforurening, användningsfall, politikker, brugerdrevet, samfundsmæssig, kan
# precipitation, rainfall, humidity, moisture, soil, eastern, extratropical, hemisphere, february, asia
# copernicus, privacy, estonian, cookies, mailerlite, slovenian, https, lithuanian, français, swedish
# mailerlite, gdpr, copernicus, email, european, data, privacy, slovenian, estonian, swedish
# copernicus, climate, solar, renewables, renewable, forecasts, energy, ecmwf, c3s, europe
# oceannews, antarctic, arctic, ocean, warming, oceanenergy, sea, temperature, heatwaves, marine
# ensemble, ensembles, multicast, multigrid, multigrille, ranked, grids, top2, agrif, top
# dust, atmospheric, atmosphere, aerosol, weather, sahara, saharan, skies, mediterranean, desert
# oceanului, oceanul, oceani, coastă, marine, serviciului, serviciul, climatice, servicii, oceanelor
# glaciers, glacier, greenland, antarctic, iceberg, antarctica, icebergs, ice, sentinel, volcano
# copernicus, italy, alps, sentinel, volcano, satellite, eruption, esa, lake, portugal
# wildfires, volcano, fires, wildfire, eruption, copernicus, forests, forest, firefighters, portugal
# climate, esotc, 2023, arctic, 2022, europe, 2021, greenhouse, temperatures, weather
# oceanography, seas, ocean, sea, seawater, marine, waters, indicators, monitoring, ecosystems
# sentinel, sentinel2go, esa, monitor, matomo, analytics, cookies, volcano, server, eruption
# monitoring, updates, file, download, site, ft, guides, manual, factsheet, validation
# baltic, sea, mediterranean, ocean, salinity, trend, anomaly, 2022, temperature, reanalysis
# analytics, cookies, gdpr, privacy, monitor, cookie, https, server, security, platform
# vegetation, leaf, biomes, canopy, raster, 1km, ndvi, reflectances, km, greenness
# temperatures, temperature, summer, seasonal, winter, summers, warmer, daytime, daytimes, europe
# snow, sar, snowfinch, sentinel, classified, fsc, resolution, sensing, metadata, raster
# humidity, precipitation, moisture, hydrological, seasonal, drying, soil, temperature, europe, southern
# zahtjevi, opazovanje, surađujemo, razvoja, razvojni, okolje, evolucije, sprejemanja, raziskovalno, savjetodavni
# monitorizarea, nws, modelis, monitorización, monitorização, nrt, modelo, modèle, modell, model
# floods, flood, flooded, flooding, eruption, copernicus, volcano, disaster, emergency, rains
# groundwater, freshwater, catchment, basin, water, basins, volcano, irrigation, environmental, inland
# mediterranean, sea, maritime, spill, oil, riskaware, vessel, ocean, malta, spills
# océaniques, océans, océan, marines, maritimes, climatique, politiques, marins, environnement, européenne
# cmems, search, estonian, scrum2, cnr, wavewatch, abstrakt, climsea, waveflow, cnrs
# copernicus, cmems_eu, marine, oceanpredict, ocean, mercator, monitoring, service, upcoming, forecasting
# въпроси, замърсяването, свързани, европейския, събития, достъп, център, морския, коперник, морски
# co2, co2m, emissions, co2mvs, carbon, greenhouse, methane, climate, atmospheric, atmosphere
# monitoring, copernicus, lake, lakes, temperature, guides, manual, download, version, site
# sea, python, plotting, visualizing, wave, visualize, tutorial, biogeochemical, environment, maps
# copernicusecmwf, copernicus, meteorological, copernicuseu, climate, ecmwf, eu, europe, forecasts, weather
# lakes, lake, waters, observations, reflectances, reflectance, sensor, dataset, inland, water
# habitats, habitat, ecological, ecosystem, landscape, biodiversity, urbanisation, forests, urban, cities
# cookies, cookie, express, browser, tracking, settings, preferences, stored, store, disabled
# phytoplankton, chlorophyll, photosynthesis, biogeochemistry, ecosystem, biogeochemical, ecosystems, ocean, organisms, carbon
# meteorological, era5, era5t, climate, atmospheric, weather, ecmwf, reanalysis, observations, dataset
# chlorophyll, ensembles, ensemble, odessa, spread, perturbing, perturbations, perturbados, radtrans, bgc
# slovenian, monitor, european, analytics, cookies, gdpr, eusso, android, czech, lithuanian
# disasters, copernicus, disaster, volcanic, eruption, volcano, crises, emergencies, landslide, crisis
# algorithm, guides, soil, document, temperature, basis, surface, site, land, vegetation
# temperatures, temperature, warmest, warming, warmer, warm, warmth, calendar, 2018, 2016
# temperatures, climate, weather, temperature, 2024, 2023, 2021, january, july, warmest
# agricultural, agriculture, crops, crop, farming, farmers, agri, agro, farm, sentinel
# copernicus, ecmwf, c3s, europa, atmosphere, eur, cjs2_160b, cjs2_030, earth, consultancy
# drom, france, martinique, départements, régions, regions, departments, european, guyana, ground
# oceanhack4eu, copernicus, marine, ocean, reefs, coral, coastal, maritime, 2024, 2023
# copernicus, marine, sea, ocean, baltic, mediterranean, mercator, training, workshop, debriefing
# mailerlite, copernicus, gdpr, mediterranean, sea, european, coastal, email, newsletter, cookies
# copernicus, marine, estonian, swedish, projekty, finnish, mercator, informacije, croatian, greek
# myocean, myocean2, oceanography, ocean, oceanteacher, marine, viewer, cmems_eu, colormaps, explore
# egms, satellite, landslides, geospatial, monitoring, landslide, geological, ground, gnss, radar
# monitorización, plástico, contaminación, por, plásticos, plastica, plástica, políticas, explicadores, poluição
# sentinel, plesetsk, esa, cosmodrome, volcano, russia, latvian, eruption, slovenian, swedish
# analytics, cookies, monitor, gdpr, matomo, slovenian, volcano, server, eruption, eusso
# climate, projections, simulations, predictions, c3s, hydrological, prediction, earth, models, projection
# oceanography, phytoplankton, seapodym, habitats, coral, marine, reef, biodiversity, whales, fish
# satellite, geostrophic, updated, arcticmix, update, roadmap, multiobs_glo_phy_w_3d_rep_015_007, vassilios, português, product
# disasters, ems, disaster, emergency, floods, maps, evacuation, cems, map, flood
# gdpr, cookies, analytics, privacy, cookie, mailerlite, european, email, newsletter, twitter
# lmtl, biomasse, global_reanalysis_bio_001_033, biomassa, zooplanktona, żooplankton, zooplankton, zoöplankton, micronekton, modeļa
# plastica, plástica, plasticului, plástico, microplásticos, plásticos, plasticul, plastic, océano, oceano
# zanieczyszczenie, zanieczyszczenia, usług, obsługi, usługi, współpracujemy, społeczna, streszczenie, według, rzecz
# estuary, estuaries, coastal, ocean, marine, salinity, oyster, atlantic, oysters, forecast
# meteorological, scientistat, terrasigna, ecologique, norway, finland, estonia, sweden, belgium, italy
# pollutants, ozone, pollution, emissions, pollutant, aerosol, emission, eruption, volcano, air
# albedo, atmosphere, solar, sun, sky, clouds, radiation, emitted, flux, metre
# environment, biodiversity, marine, renewable, oceana, ocean, habitat, conservation, ytoplankton, species
# insitu_glo_ts_oa_nrt_observations_013_002_a, insitu_glo_nrt_observations_013_030, insitu_glo_uv_nrt_observations_013_048, insitu_bal_nrt_observations_013_032, insitu_med_nrt_observations_013_035, insitu_glo_ts_oa_rep_observations_013_002_b, insitu_bs_nrt_observations_013_034, insitu_ibi_nrt_observations_013_033, insitu_glo_ts_rep_observations_013_001_b, insitu_arc_nrt_observations_013_031
# api, clms_hrsi_arlie_downloader, http, downloading, hda, portal, finder, website, download, hdar
# copernicus, earthquake, emergency, italy, embassy, floods, italiano, consulate, ems, flood
# glaciers, glacier, alps, antarctic, antarctica, ice, glaciological, observations, fluctuations, greenland
# 2023, 2022, temperatures, temperature, 2021, equatorial, 2020, december, antarctica, february
# hive, projektet, prognoser, het, ranked, en, voor, evaluation, modellen, km
# arctic, ice, climate, radar, eumetsat, sea, temperature, satellite, sensors, esa
# temperatures, ocean, temperature, equatorial, atlantic, sea, gulf, warming, sst, ssts
# copernicusecmwf, ecmwf, copernicus, meteorological, copernicuseu, esa, forecasts, eumetsat, eu, satellites
# dataset, metadata, sea, océan, marine, resource, mercator, sst, classification, osi
# seas, maritime, marine, oceanic, eu, coastal, ocean, atlantic, eutrophication, seacras
# κλείστε, και, περίληψη, greek, συνεργάτες, estonian, cmems, οργάνωση, bioptimod, finnish
# dataset, satellites, eumetsat, satellite, metadata, meteosat, sentinel, iasi, osi, sensor
# sentinel2, vega, vv05, spaceport, vv09, monitor, mission, oman, platform, slovenian
# sossta, storto, cmems, cmcc, massimili, aies, română, andrea, scrum, medsub
# copernicus, oceanhack4eu, ocean, marine, reefs, 2024, 2023, coral, coastal, forecasting
# coastal, coast, sea, beaches, nearshore, coastserv, offshore, marine, island, waters
# copernicus, sofia, volcano, european, eruption, czech, bulgarian, events, prague, event
# въздействието, приложения, достъп, коперник, атлантическия, подобрения, проекти, споразумение, информация, морските
# estonian, käyttöönottostrategia, finnish, seurantaennustekeskus, koostekeskus, kansallinen, käyttäjien, kehitysstrategia, kasutuselevõtu, sidosryhmien
# meeresbeobachtung, serviceentwicklungsstrategie, plastikverschmutzung, beratungskomitee, sensibilisierung, nutzerakzeptanz, europäischen, forschungs, entwicklungsprojekte, meeresakteure
# sentinel, aerosols, gases, tropomi, volcano, dioxide, esa, nitrogen, monoxide, eruption
# pollens, pollen, allergies, allergy, meteorological, allergens, allergic, sneezing, hay, aeroallergen
# cookie, cookies, prijímajte, přijímejte, přijmout, zijn, geaccepteerd, blokován, je, webovej
# raster100m, specifications, imperviousness, resolution, impervious, raster20m, datasets, dataset, clms, accuracy
# sistēmu, sistēmām, virpuļviesuļu, atgriezeniskās, atsižvelgiant, informācijas, attēlā, atgriezenisko, izšķirtspējas, owairs
# arcticmix, projektu, ubezpieczeniowych, parametrizāciju, arktycznym, podwójnego, morskiego, dyfuzyjnego, przez, sajaukšanās
# resolution, sentinel, ice, snow, pixels, sar, lakes, geographical, rlie, arlie
# разпространението, достатъчно, например, изпратете, списък, център, въглеродна, образование, употреба, бъдат
# επικοινωνίας, πρωτοβουλίας, ωκεανούς, διακυβέρνηση, εκδηλώσεις, στις, θαλάσσια, πληροφορίες, υπηρεσίας, τελευταία
# estonian, europese, voor, croatian, slovenian, adviescomité, samenwerken, producten, latvian, cmems
# satellite, sentinel, plesetsk, cosmodrome, mission, orbit, esa, russia, guiana, radar
# temperatures, meteorological, temperature, colder, warming, warmest, noaa, dataset, datasets, estimates
# cookies, αποδεχτείτε, ποιες, αποκλεισμός, χρησιμοποιούνται, προγράμματος, αυτό, μπλοκαρισμένο, αυτόν, αποδοχή
# baltice, baltică, báltico, baltico, baltic, salinity, salinității, salinitatea, salinidade, saliniteta
# εικόνες, χρησιμοποιούνται, πολιτικές, περιπτώσεις, ένας, θαλάσσιας, δεσμεύσεις, στις, δείκτες, υπηρεσίας
# climate, training, learners, learning, c3s, program, interactive, svg, resources, trainer
# climate, meteorology, indicators, tourism, resorts, tourists, touristic, tourist, resort, weather
# sampling, ecmwf, ensemble, averaged, thinning, genoa, cmems, uncertainty, ora, 70m
# biodiversity, ecosystem, ecological, species, habitats, habitat, conservation, volcano, sensing, alien
# volcano, eruption, teleconference, cso_agenda, indonesia, portugal, laki, eusso, european, portuguese
# estonian, greenup, croatian, search, finnish, cmems, slovenian, cls, hungarian, swedish
# floods, rainfall, river, danube, drought, flood, catchments, rivers, flooding, precipitation
# oceanpredict, copernicus, ocean, marine, coastal, maritime, 2023, forecasting, arctic, 2022
# copernicus, ocean, oceanpredict, marine, upcoming, forecasting, 2022, cmems_eu, 2024, polar
# arctic, icysea, antarctic, maritime, shipcapp, polarview, ships, navigation, sea, greenland
# volcano, eruption, slovenian, ecosistema, indonesia, mount, laki, eusso, czech, latvian
# precipitation, rainfall, europe, seasonal, rain, winter, moisture, summer, alps, wettest
# genoa, opazovanj, lähenemisviisiga, nenoteiktības, przerzedzania, generuje, zespołowym, negotovosti, pozorovaní, pozorování
# winds, coastline, currents, kailani, wind, rmsd, directional, zones, southward, predicts
# climate, temperatures, temperature, colder, antarctica, winter, warmest, siberia, warmer, february
# seaports, baltic, coastal, seas, harbour, coastlines, sea, seabed, latvia, forecast
# cookies, cookie, carbonate, zablokowana, zablokovaný, oxygen, zaakceptowane, zostały, küpsistega, užblokuotas
# océaniques, cookies, les, cookie, ce, océan, marin, marines, le, secteur
# seasonal, adeos, scandinavian, snow, ais, sinusoidal, interferometric, estuario, stéphane, insar
# soyuz, copernicus, estonian, composite, vs14, croatian, bulgarian, slovenian, polish, hungarian
# vegetation, land, croplands, forests, grassland, cover, grasslands, forest, accuracy, cropland
# zones, atlas, land, dataset, clms, mapping, shapefile, europe, area, lc
# projektai, lithuanian, čempionu, technikos, latvian, sektoriaus, piesaistes, tematiskās, stebėjimo, reikalavimai
# gmes, gse, symposium, organisations, icos, ec, pangeo, services, operational, dissemination
# ocroc, ocr, sveučilište, search, slovenian, cosi, antoine, français, hungarian, lucile
# radarja, radar, radarskih, radara, radaras, radarových, radaru, visokofrekventni, osiguranje, nekoliko
# reefs, coral, corals, reef, marine, oceans, ocean, ecosystems, biodiversity, warming
# diurnal, variability, variance, sst, seviri, hourly, divost, simulations, blue, day
# eea38, geotiff, mosaic, europe, tiles, km, raster, datasets, resolution, belgium
# climate, agriculture, crops, agricultural, greenhouse, crop, forestry, farming, harvest, wheat
# volcanic, volcanoes, volcano, eruptions, eruption, erupted, plumes, plume, atmospheric, atmosphere
# chlorophyll, chlorophylle, biogeochemical, hive, efflorescences, blooms, bio, amm7v11, colours, amm7v8
# soda, projekta, sensores, sargassumului, operativa, operativni, sensoren, odkrivanje, produtos, sargassuma
# cso_listofcopernicusrelaysmembers_v, volcano, eruption, slovenian, cookies, laki, monitor, analytics, indonesia, mount
# oceaanstromingen, oceaan, veranderingen, verslag, europese, praktijkvoorbeelden, instellingen, bedreigingen, voortvloeien, oceanografie
# modellerna, modeller, processer, och, analyser, systemer, modellen, av, observationer, satellitobservationer
# meteorological, precipitation, climatology, temperature, estimates, geopotential, datasets, data, dataset, winter
# waves, wave, winds, frequencies, wind, spectrum, sea, storms, swell, heights
# oceans, ocean, sea, sonar, coastal, gulf, coast, maritime, marine, mediterranean
# reanalysis, meteorological, reanalyses, climate, atmospheric, noaa, pacific, observations, assimilation, ecmwf
# meteorological, csv, precipitation, radiosoundings, observations, radiosounding, dataset, stations, uncertainties, radiosonde
# baltic, atlantic, arctic, european, régiónként, mediterranean, regiónov, nederlands, sea, slovak
# copernicus, monitoring, services, service, clms, seaborne, terrestrial, environment, vegetation, thematic
# összefoglaló, műanyagszennyezés, események, kopernikusz, hungarian, eszközöket, élelmezésbiztonság, közegészségügy, óceánok, növekedés
# vega, sentinel, vv09, esa, guiana, satellite, cet, kourou, mission, laki
# climate, copernicus, temperatures, meteorological, temperature, weather, forecasts, eu, eumetsat, atmosphere
# forestry, deforestation, forestsat, forests, forest, tree, ecosystems, tropical, volcano, eruption
# gender, women, copernicus, female, woman, opportunities, workplace, careers, career, gi
# marinedata4, marinedata4africa, marinedata4asia, marinedata4southamerica, ocean, jupyter, notebooks, zooplanktona, zooplanktonu, intermediate
# oceanhack4eu, ocean, marine, maritime, 2024, 2028, eu, dof2024, digital, forecasting
# oceana, oceanen, óceán, ocean, oceánu, oceanu, modelování, modeliranje, modellezése, modellek
# meteorology, geosciences, stac, ionospheric, scientist, smith, chairman, expertise, mercator, advisory
# leaf, monitoring, copernicus, sentinel, vegetation, canopy, index, area, 1km, guides
# μοντέλων, χρησιμοποιώντας, μοντέλα, αλατότητας, μοντέλου, μοντέλο, αποτελέσματα, λεκάνης, άλλες, ποταμών
# sst_atl_sst_l4_rep_observations_010_026, sst_atl_phy_l3s_my_010_038, sealevel_glo_phy_climate_l4_my_008_057, sst, 25deg_p1m, dataset, mdt, tide, c3s_obs, duacs
# temperatures, october, temperature, colder, november, antarctica, december, warmest, january, warmer
# sst_nws_sst_l4_nrt_observations_010_025, sst_bal_sst_l4_nrt_observations_010_007_b, sst_nws_sst_l4_nrt_observations_010_0, sst_nws_sst_l4_rep_observations_010_026, sst_nws_sst_l4_rep_observations_010_02, sst_bal_sst_l4_rep_observations_010_016, sst_bal_sst_l3s_nrt_observations_010_032, sst_glo_sst_l4_nrt_observations_010_014, sst_glo_sst_l4_nrt_observations_010_005, sst_bs_sst_l4_nrt_observations_010_006
# s1_202301010000_globe_olci_v1, geotiff, s2_202301010000_globe_olci_v1, raster, data, c_gls_lsp300, resolution, metocean, global, 2023
# ai4copernicus_technical, ai4coper, sentinel, docker, pipeline, landseamask, glint, speckle, documentation_v5_feb2023_cover, documentation
# ozeanographie, ozeane, ozean, meeresumwelt, wirtschaft, meereszustandsbericht, ozeans, herausgegeben, geschichte, weltmeere
# spaceapp, esa, volcano, frascati, camp, apps, eruption, app, space, laki
# contatto, personali, informații, momento, confidențialitatea, protezione, trattamento, personale, dati, servizio
# copernicus, ecmwf, earth, cet, svg, climate, europe, conference, h3, e2164dea
# sentinel, multires, resolutie, figura, multi, resolução, productos, prodotti, risoluzione, résolution
# radiometer, cosi, radiometru, radiometra, sa, amsr2, observações, waarnemingen, projektu, km
# copernicus, ocean, oceanhack4eu, coastal, marine, arctic, forecasting, mercator, 2023, 2024
# nasa, meteorological, datasets, data, climate, archives, noaa, rescue, satellite, observations
# oceandecade, coastal, assimilation, ocean, coastpredict, ensembles, atmospheric, multicast, ensemble, multigrid
# παραμετροποιήσεις, στις, μοντέλων, μέγιστων, ατμόσφαιρας, συστήματος, μοντέλα, αποτελέσματα, κυματικό, κλίμακες
# geostationary, temperature, mtsat, sensors, sensor, sky, km, lst10, pixel, thermal
# radarsat, instrumentos, sar, radar, sateliti, instrumenta, satelit, instrumenti, instruments, instrument
# volcano, volcanic, volcanoes, eruptions, eruption, erupted, lava, magma, copernicus, hawaii
# soyuz, satellite, mission, laki, vs14, sentinel, orbit, hoisted, tower, cubesats
# vegetation, yearly, 2023, dataset, phenology, season, plant, metadata, 07, clms
# sentinel, satellites, satellite, mission, constellation, esa, orbit, orbiting, cubesats, 1b
# arctic, copernicus, climate, satellites, polar, iceberg, ice, radar, sentinel, geopolitical
# copernicus, sentinel, satellites, satellite, ocean, radar, nasa, sea, calibrate, esa
# atmospheric, atmosphere, enthalpy, flux, energy, eastward, ozone, thermal, geopotential, northward
# orography, orographic, wind, turbulent, eastward, mountains, forecasting, buoyancy, reanalysis, valleys
# seaports, sea, coastal, maritime, harbour, seabed, sediment, romania, pollution, baltic
# copernicus, oceanpredict, ocean, oceanhack4eu, marine, arctic, reefs, 2023, forecasting, 2024
# estuary, estuario, latitude, maree, advekcija, dimauro, costa, nature, pinardi, salt
# μιας, γειτονιές, γειτονιάς, hive, προβλέψεις, μετρικές, βαθμολογίες, έχει, χιλιομέτρων, γειτονιά
# sentinel, satellite, esa, mission, vega, constellation, volcanic, guiana, 2b, eruptions
# altimeter, altimetry, altimeters, seas, sea, ocean, glacial, coastal, mesoscale, glaciers
# scrum2, ensembles, scrum, consistência, ensemble, ens1, 1sst_glo_sst_l4_nrt_observations_010_001, en, diagrama, ens
# sentinel, satellites, satellite, cosmodrome, orbit, plesetsk, volcano, constellation, esa, eruption
# maritime, sea, ships, shipcapp, antarctic, icysea, coast, coastal, ocean, arctic
# atmospheric, atmosphere, greenhouse, forecasts, cams, observations, ecmwf, global, forecasting, 2022
# leda, led, promjene, morskog, ledenih, ledenog, također, morskega, ledové, ledom
# radar, sentinel, sar, satellite, antenna, orbit, esa, aperture, matomo, guiana
# eksempler, strømninger, aktører, sektor, støtte, øhavets, kan, accepteret, och, blokeret
# temperatures, temperature, august, climate, summer, summers, july, antarctica, warmest, warmer
# copernicus, temperatures, climate, temperature, warmest, warming, volcano, eruption, summer, indonesia
# plastmasas, plastmasa, plastmasu, plastikinių, plastiku, piesārņojumu, plastikas, piesārņojumam, piesārņojums, piesārņojuma
# drom, coordinate, grids, droms, ortho, epsg, grid, calibrated, martinique, utm
# salinity, salinidade, salinidad, salinité, salinità, estuario, estuário, fluviales, modelos, como
# seaice_arc_seaice_l3_nrt_observations_011_014, seaice_arc_seaice_l4_nrt_observations_011_007, seaice_bal_seaice_l4_nrt_observations_011_004, seaice_arc_seaice_l4_nrt_observations_011_008, seaice_arc_seaice_l4_nrt_observations_011_002, seaice_glo_seaice_l4_nrt_observations_011_006, seaice_bal_seaice_l4_nrt_observations_011_011, seaice_ant_seaice_l4_nrt_observations_011_012, seaice_arc_seaice_l3_rep_observations_011_013, seaice_arc_seaice_l3_rep_observations_011_010
# copernicus, ecmwf, meteorological, eumetsat, eu, esa, satellites, climate, forecasts, monitoring
# forecasts, wind, wavewatch, waveflow, hemisphere, wave, earth, tropics, zu10, forcing
# renewables, renewable, solar, climate, photovoltaic, turbines, electricity, europe, energy, winds
# sentinel, copernicus, cookies, fairing, 3a, accept, greek, encapsulated, rockot, estonian
# sentinel, volcano, cosmodrome, mission, plesetsk, eruption, esa, mount, russia, launch
# lambda, search, cmems, scrum2, terra, maretec, pcoms, και, καλύτερη, regionale
# aceites, aceptado, aceitar, oceânicas, oceánicas, conteúdo, cookies, productos, aceptar, salinidade
# gdpr, analytics, cookies, privacy, mailerlite, email, european, https, twitter, newsletter
# ledus, ledas, ledu, ledo, sasilšana, jūras, jūrų, kartus, paviršiaus, izraisa
# offshore, renewable, turbines, tidal, wind, ocean, waves, wave, coast, marine
# privacy, data, eu, information, registration, europa, ec, provider, electronically, regulation
# copernicus, satellites, sentinel, satellite, esa, cloud, data, apis, ecosystem, cube
# sentinel, satellite, esa, mission, guiana, volcano, payload, mount, spaceport, kourou
# arctic, warming, temperatures, temperature, colder, warmest, greenland, warmer, svalbard, warm
# soil, raster, moisture, scatterometer, index, land, km, wetness, water, assessed
# climate, meteorology, temperatures, weather, mitigation, mortality, risks, heatwave, resilience, thermal
# vegetation, guides, monitoring, manual, navigation, download, file, index, normalised, document
# antarctic, arctic, february, march, month, monthly, ice, october, september, august
# search, content, page, cmems, news, explore, estonian, skip, faq, language
# цъфтежи, съседство, тъй, анализът, към, пространствени, твърде, размери, например, километричен
# forecasting, monitoring, mfc, advisory, ambiente, meeresbeobachtung, serviceentwicklungsstrategie, mediterranean, ibi, iberia
# datacube, jupyterhub, dates, python, wekeo, viewer, wekeo4land, data, api, jupyter
# nautical, sailing, sailgrib, sailboats, oceanics, navigation, sailors, routes, boat, skipper
# clc, revision, revisions, changes, 2000, l1c, revised, gfsc, spain, eu
# sea, tides, oceanog, gliders, sailing, glider, gliding, floats, drifting, zooplankton
# atlas, urbanisation, volcano, urban, cities, eu, eruption, european, indonesia, portugal
# océaniques, vagues, océan, vague, vague2nemo, paramètres, océanique, entre, en, modèles
# projekter, europæiske, projekten, och, projekterne, swedish, videnskabeligt, projekt, tjenester, serviceudvikling
# cameroon, landscapes, africa, madagascar, forests, landscape, caribbean, timor, areas, conservation
# c3s, climate, c3s2_461, collaboration, ecmwf, earth, ncp, coordination, services, programme
# στις, συστοιχίες, στους, τομείς, δομές, τιμές, κάποιες, συστοιχίας, στον, συνδέονται
# aerosol, albedo, emissions, sky, carbon, dust, methane, nitrogen, precipitation, ammonia
# visualisation, visualize, visualise, icon, visualised, layer, map, widget, layers, datasets
# estuario, gianolla, giorgia, alessandro, climatici, cambiamenti, itálie, italie, italië, mediterraneo
# resolution, snow, sar, sentinel, pixels, fsc, spatial, psa, range, gfsc
# windstorms, windstorm, storms, storm, insurance, wind, insurers, climate, reinsurers, indicators
# golfmodellen, golfproducten, golfmodel, golfhoogte, golf2nemo, golf, voorspellingen, waveflow, gevolgd, voor
# sahara, desert, dunes, gulf, libya, volcano, arabia, tunis, algeria, sand
# decorrelation, radar, noisy, plots, satellite, ground, movements, outliers, correlation, displacements
# oceanografische, oceanografska, oceanographic, oceanográfiai, oceanografică, oceánografická, oceanografskih, oceánografických, oceanima, unesco
# estuary, coastal, ocean, portugal, salinity, fishes, offshore, marine, macroinvertebrate, coast
# sealevel_eur_phy_l4_nrt_observations_008_060, mesoscale, sealevel_glo_phy_l4_nrt_008_046, geostrophic, sealevel_eur_phy_l3_nrt_008_059, geophysical, l4, sea, ocean, topography
# clc, geographic, countries, 211, 2023, consumption, accuracy, 2024, ocean, validating
# sentinel, satellite, esa, guiana, netherlands, constellation, volcano, mission, multispectral, eruption
# climate, training, learning, hydrology, climatologists, resources, consultant, registration, enrolment, certificate
# arctic, antarctic, polarview, polar, svalbard, norwegian, norway, ice, warming, observing
# cookies, slovenian, enabled, monitor, laki, eusso, analytics, estonian, lithuanian, gdpr
# voyopt, cuag, maritime, voyage, ships, metocean, vessel, consortiums, marine, sail
# climate, sunshine, solar, mean_sunshine_baseperiod, clouds, cloud, satellite, eumetsat, europe, radiation
# salinity, geoserver, geoserveru, lambda, sqlserver, surface, web, map, dataportalen, mediterrranean
# seals, marine, oceanic, fauna, micronekton, turtles, wildlife, pollution, biomass, sustainable
# copernicus, monitoring, ec, probeck, planetek, geos, environment, coastal, eurogi, aarhus
# sentinel, satellites, esa, missions, plesetsk, cookies, mission, gdpr, orbiting, analytics
# oceans, marine, ocean, coral, aquarium, awareness, initiatives, organizations, outreach, partnerships
# повърхност, въглерод, повърхността, фитопланктонът, вълни, вълните, първото, гори, вълната, глосар
# zdroje, zaregistrujte, zapojení, bioraznolikosti, zapojenie, případů, prípadov, zaregistrovat, použití, praćenje
# insitu_glo_phy_uv_discrete_my_013_044, insitu_glo_wav_discrete_my_013_045, ocean, cfconventions, netcdf, insitu_glo_phy_ts_oa_nrt_013_002, ins_glo_phy_cur_my_drifter_, featuretype, marine, global
# cyclone, madagascar, mozambique, landfall, volcano, eruption, floods, malawi, tropical, storm
# european, copernicus, sentinel, gdpr, slovenian, estonian, lithuanian, latvian, bulgarian, swedish
# solar, sun, photovoltaic, irradiance, radiation, atmosphere, irradiation, renewable, sky, geostationary
# cmems_obs_oc_blk_bgc_geophy_nrt_l4, netcdf, cmems_obs_oc_blk_bgc_transp_nrt_l4, ins_glo_phy_cur_my_drifter_pt1h, cmems_obs_oc_blk_bgc_optics_nrt_l4, cmems_obs, insitu_glo_phy_uv_discrete_my_013_044, oceancolour_blk_bgc_hr_l4_nrt_009_212, cmems, gl_ts_dc_
# soyuz, transfer, estonian, copernicus, bulgarian, gdpr, european, slovenian, croatian, czech
# проектът, въздействието, свързването, обърне, събитие, граничните, границите, отрицателни, върху, граница
# java, programmatūras, radardata, radarprodukter, software, hfr_combiner_tirlig, matlab, radar, formato, netcdf
# zooplankton, chlorophyll, seapodym, micronekton, biomass, climatology, copepod, bats, mammal, lmtl
# amm7, modelos, amm15, comparação, como, métricas, objectos, puntuaciones, previsões, previsão
# geojson, csv, geopackage, file, compression, zip, formats, myfile, epsg, declared
# northwestshelf_analysis_forecast_bio_004_002_b, northwestshelf_analisi_forecast_bio_004_002_b, noordwestshelf_analysis_forecast_bio_004_002_b, northwestshelf_analysis_forecast_phys_004_001_b, northwestshelf_analysis_forecast_phy_004_013, oceancolour_atl_chl_l4_nrt_observations_009_037, sst_nws_sst_l4_nrt_observations_010_003, insitu_nws_nrt_observations_013_036, ibi_analysis_forecast_phys_005_001, hive
# gulf, geostrophic, dimup, vorticity, quasigeostrophic, globcurrent, drifteris, drifters, reconstructed, current
# salinity, estuario, estuariene, sensitivity, estuarijų, geosciences, estuarinas, benchmark, cherubini, yellow
# съсредоточихме, ансамбъл, ансамбъла, съгласуваността, възрастта, първа, стъпка, към, scrum2, върху
# baltic, finland, finnish, icysea, ice, icebreaker, oceanographic, sea, fmi, coastal
# ozone, emissions, atmosphere, pollution, pollutants, tropospheric, pollutant, smog, sunlight, forecasts
# soyuz, mik, spaceport, vs07, laki, satellites, rocket, corvaja, indonesia, guiana
# dataset, insitu_observations_woudc_ozone_total_column_and_profiles, satellite_sea_surface_temperature_ensemble_product, cams_europe_air_quality_forecasts_optimised_at_observation_sites, satellite_sea_ice_edge_type, metadata, satellite_sea_level_global, ecmwf, cems_fire_seasonal, sis_marine_properties
# reefs, reef, seabed, ecosystem, habitats, marine, sea, habitatdirektivet, baltic, habitat
# cookies, analytics, cookie, gdpr, privacy, https, security, monitor, website, server
# copernicus, antarctic, oceanchallenge4africa, ocean, sea, marseille, coasts, mediterranean, 2022, marine
# mediterranei, mediterraneo, temperatura, uragani, identificato, températures, mare, nella, écosystèmes, océans
# 0625deg_p1m, ssh_my_allsat, ssh_myint_allsat, 0625deg_p1d, 125deg_p1d, cmems_obs, insitu_glo_phy_ts_oa_nrt_013_002, sl_eur_phy, datasets, produktu
# mohid, modelling, lambda, modelis, model, modell, modèle, modellen, modello, modelul
# oceancolour_glo_bgc_l4_my_009_104, oceancolour_atl_bgc_l4_my_009_118, wave_glo_phy_spc_fwk_l3_nrt_014_002, wave_glo_wav_l3_spc_nrt_observations_014_002, sealevel_eur_phy_l4_nrt_observations_008_060, plankton_my_l4, 4km_p1m, oc_atl_bgc, rename, 1km_p1m
# africa, african, earth, gmes, volcano, eusso, auc, eruption, eumetcast, european
# mediterranei, mediterraneo, mediterranean, anticipo, italiano, temperatura, extratropicali, identificato, cicloni, una
# scrum2, forecast, ecmwf, ensembles, ensemble, cmems, sst, stochastic, m3, cr
# forecast, forecasts, rmse, amsr2, oceanic, cryosphere, ice, sea, learning, models
# oceancolour_atl_bgc_l4_my_009_118, oceancolour_glo_bgc_l4_my_009_104, fes_2014, coast, tide, l4, fes_2022, l3, sealevel_eur_phy_l3_my_008_061, sla
# dataset, clms_global_swe_5km_v1_daily_netcdf, clms_global_lie_500m_v1_daily_netcdf, clms_global_ssm_1km_v1_daily_netcdf, clms_global_sce_500m_v1_daily_netcdf, clms_global_lst_5km_v1_10daily, clms_global_wb_100m_v1_monthly_netcdf, metadata, clms_global_fapar_1km_v1_10daily_netcdf, clms_global_lst_5km_v1_hourly_netcdf
# gdpr, analytics, european, cookies, mailerlite, privacy, twitter, email, newsletter, https
# multiobs_glo_bio_carbon_surface_rep_015_008, multiobs_glo_phy_s_surface_mynrt_015_013, multiobs_glo_bio_bgc_3d_rep_015_010, multiobs_glo_bio_nutrients_profiles_rep_015_009, multiobs_glo_phy_tsuv_3d_mynrt_015_012, multiobs_glo_phy_nrt_015_003, multiobs_glo_phy_w_3d_rep_015_007, multiobs_glo_phy_rep_015_004, globālā, carbonio
# praktijkvoorbeelden, oceaanklimaat, europese, instrumenten, wordt, voor, stedelijke, evenementen, ondersteunen, het
# stormgeo, oceanographer, oceanography, offshore, ships, fleet, ship, onshore, hull, weather
# mediterraneo, mediterranei, meteorologiche, tropicales, temperatura, océane, océan, extratropicali, mare, scientifica
# mediterranean, température, mediterráneo, mediterraneo, temperaturas, méditerranée, highest, july, 2024, el
# emodnet, marine, ec, eu, maritime, ocean, atlantic, infrastructures, services, seabed
# wind_bal_phy_hr_l3_my_012_107, wind_arc_phy_hr_l3_my_012_105, wind_atl_phy_hr_l3_my_012_106, wind_blk_phy_hr_l3_my_012_108, wind_med_phy_hr_l3_my_012_109, multiobs_glo_phy_w_3d_rep_015_007, cmems_obs, sealevel_eur_phy_l3_my_008_061, wind, sealevel_glo_phy_l3_my_008_062
# divost, estonian, diurna, finnish, cmems, karagali, de, dmi, lithuanian, croatian
# océanographie, aquatic, ecosystems, atlantic, freshwater, silió, sciences, cuag, ihcantabria, curie
# océanographe, océanographie, océans, océan, maritimes, scientifiques, marin, dans, português, environ
# ocean, oceanpredict, copernicus, forecasting, coastal, marine, arctic, oceaangezondheid, architecture, prediction
# sentinel, copernicus, privacy, satellite, mailerlite, estonian, liftoff, https, cookies, slovenian
# netcdf, dataset, km, files, download, file, vegetation, monitoring, website, raster
# mosaics, mosaic, coverage, resolution, vegetation, metadata, images, raster20m, clms, updates
# curae, search, cmems, climsea, arcilla, main, continentale, upc, español, estonian
# zones, land, be001l2_bruxelles_brussel, graz, dataset, europe, area, bruxelles, atlas, geotiff
# oceanic, ecosystems, freshwater, amphitrite, spectral, ihcantabria, sensor, ibm, planetek, models
# planetek, sar, environment, andersson, sensing, environments, rheticus, optical, projects, engineer
# oceanographic, oceanography, storto, assimilation, seas, coastpredict, advisory, wcrp, andrea, iocs
# océano, oceano, oceanului, océan, ocean, modelización, modelo, modèles, modelação, modelling
# climatici, finlandia, température, cambiamenti, euronews, warmes, écosystèmes, scoppiati, unzureichenden, lapponia
# suez, coastal, offshore, cuag, plume, pétrole, renewable, euskadi, forecasting, hydrodynamics
# copernicus, pollution, aerosols, aerosol, cookies, estonian, monitoring, slovenian, lithuanian, air
# océan, co2, 2024, euronews, dioxide, europeo, carbon, plants, températures, organización
# sst_med_sst_l4_rep_observations_010_021, sst_bs_sst_l4_rep_observations_010_022, sst_atl_sst_l4_rep_observations_010_026, sst_bs_phy_l3s_my_010_041, sst_med_phy_l3s_my_010_042, sst_atl_phy_l3s_my_010_038, sst, sealevel_eur_phy_l4_my_008_068, climate, l4
# oceanographic, cetacean, coastal, paola, romagna, ecology, emilia, italy, habitat, cuag
# baltic, lagoon, coastal, lithuania, lithuanian, sektor, sea, marine, inovacije, monitoring
# waveflow, bølgeinformation, wavewatch, atmosfære, wave2nemo, vågforceringen, cirkulationen, strøm, bølgeforcering, kvaliteten
# projekty, prognózovanie, monitoringa, stratégia, prognožu, monitorování, pracujeme, čempionu, stratēģija, spolupracujeme
# arcticmix, arctic, oceánu, oceano, estonian, fabrice, claude, swedish, finnish, croatian
# clc, clc2012, backdating, dataset, updates, shapefile, files, coverages, changes, countries
# sealevel_glo_phy_climate_l4_my_008_057, sealevel_eur_phy_l3_my_008_061, sealevel_eur_phy_l4_my_008_068, sealevel_glo_noise_l4_rep_observations_008_033, sealevel_glo_phy_mdt_008_063, sealevel_eur_phy_l3_, sealevel_blk_phy_mdt_l4_static_008_067, sealevel_eur_phy_l4_, sealevel_eur_phy_l3, sealevel_med_phy_mdt_l4_static_008_066
# phytoplankton, co2, plankton, carbon, zooplankton, carbonate, inorganic, micronekton, sea, spco2
# seagrass, érosion, erosion, eroded, planting, reduced, curve, réduction, reduction, environment
# salinity, oceanico, atlantic, renumereren, numerico, en4, modelling, renumerata, modeļa, globale
# soda, search, jacques, français, co, cls, françois, lithuanian, estonian, sargassums
# oceanography, copernicus, 2022, ocean, 2024, marine, coastal, forecasting, arctic, polar
# lakes, lake, temperatures, temperature, climate, warming, summer, warmest, warmer, warm
# wave2nemo, omi_extreme_wave_blksea_wave_power, estonian, joanna, hzg, mywave, română, croatian, staneva, vague2nemo
# copernicusecmwf, copernicuseu, copernicus, ai4copernicus, earth, cookies, slovenian, estonian, observation, français
# sentinel, satellite, cosmodrome, plesetsk, radar, mission, volcano, orbit, eruption, esa
# χρησιμοποιώντας, φωλιασμένο, επιχειρησιακές, μετρικές, μοντέλα, δυνατότητες, δοκιμάσαμε, μας, οικοσυστήματος, πολυπλέγματος
# oceanhack4eu, oceanpredict, maritime, marine, 2024, coastal, 2025, future, shoreline, launched
# hive, cmems, scrum2, search, climsea, estonian, lmtl, metoffice, lithuanian, genoa
# massimili, cmems, gianpiero, spalvos, italiano, bio, heloise, mio, search, organizacija
# offshorenavigation, voyopt, h2020, projetos, copernicus, marine, projektu, voyage, planeamento, cmemsforh2020
# cosi, čoskoro, slovenian, co, czech, croatian, estonian, técnicas, lithuanian, slovak
# seaports, sea, coastal, oceanpredict, ocean, marine, forecasts, romanian, forecasting, navigation
# owairs, estonian, oceaangolf, waardeketen, finnish, search, swedish, danish, en, ondes
# renumerate, renumerar, renumēt, renumerata, renumerat, renumereren, renumerado, renumerointi, renumerovať, renumerer
# sentinel, satellite, copernicus, radio, cookies, estonian, slovenian, lithuanian, français, latvian
# sentinel, satellite, esa, guiana, volcano, kourou, monitor, eruption, indonesia, laki
# multires, multi, search, cosi, português, liègeu, coastal, univerzita, aida, koncentracija
# vegetation, grassland, seasonal, metadata, dataset, raster, trajectories, 04, yearly, environments
# medsub, csic, cmems, search, italiano, română, socib, main, massimili, submezoměřítkových
# runoff, lambda, sss, watershed, river, salinity, timeseries, smos, salinité, system
# 3da, scrum2, search, estonian, ocean, croatian, română, abstrakt, climsea, genoa
# sentinel, volcano, eruption, esa, mount, launcher, laki, lithuanian, slovenian, monitor
# lmtl, cls, cmems, micronekton, search, estonian, climsea, funktionelle, scrum2, abstrakt
# 4dvarnet, estonian, oceandatalab, multires, français, croatian, latvian, search, hungarian, ofda
# fisheries, fish, habitat, marine, projekciju, stebėsenoje, zvejniecības, zvejniecībā, lähenemisviisi, pieeju
# wambor, estonian, magellium, search, gilles, cnr, slovenian, coastal, français, croatian
# fisheries, fishery, aquaculture, fish, fishermen, fishing, oceanography, map2fish, skyfish, sea
# bioptimod, bio, biogeoquímicos, biomasa, cmems, biooptický, med, biomassa, scrum2, platforme
# plasticvervuiling, plastics, microplastics, plastic, debris, macroplastics, seawater, oppervlakte, oceaanoppervlak, oceanen
# optima, optische, search, cmems, ópticos, estonian, sistema, optical, pml, croatian
# copernicus, 2024, marine, oceans, 2028, sentinels, coastal, mercator, 2021, ecosystems
# genoa, italiano, oċeani, oceanice, search, en, oceana, climsea, aspektem, scrum2
# climsea, search, scrum2, báltico, estonian, genoa, regionale, croatian, globale, klimato
# search, oceanográficos, dimup, ocean, datasynergier, skip, diagnosticar, page, main, estonian
# multicast, multires, multi, croatian, estonian, swedish, search, finnish, lithuanian, slovenian
# sealevel_eur_phy_l3_nrt_008_059, sealevel_glo_phy_l3_nrt_008_044, sealevel_glo_phy_climate_l4_my_008_057, sealevel_glo_phy_l4_nrt_008_046, l3, l4, altimeter, l2, geophysical, nrt
# glophyts, fitoplankton, fitoplanktona, glofiti, coastal, globales, globale, glofitos, globali, estonian
# copernicusems, cookies, analytics, gdpr, maps, privacy, emsr325, map, emergency, server
# temperatures, septembers, september, temperature, warmest, warmer, 2023, antarctic, october, antarctica

# %%
prompt = """Topic: {topic}

Content of documents: 
{documents}

Generated questions:
"""

max_prompt = 10000 # 4096
# model = "meta-llama/Meta-Llama-3.1-8B-Instruct-Turbo"
# model = "meta-llama/Meta-Llama-3.1-70B-Instruct-Turbo

def make_llm_call(sys_message, text, model):
    response = client.chat.completions.create(
        model=model,
        messages=[
            {"role": "system", "content": sys_message},
            {"role": "user", "content": text}
        ],
        stream=False
    )
    # import pdb; pdb.set_trace()
    return response.choices[0].message.content.split('\n')

def get_questions(topic_model, topic_id, sys_message, model):
    topics_data = topic_model.topic_representations_[topic_id]
    topic = ", ".join([x[0] for x in topics_data])
    docs = topic_model.representative_docs_[topic_id]
    local_prompt = prompt[:]
    local_prompt = local_prompt.replace("{topic}", topic)
    max_docs_chars = max_prompt - len(sys_message) - len(local_prompt.replace("{documents}", ""))
    docs = '\n\n'.join(docs)[:max_docs_chars]
    local_prompt = local_prompt.replace("{documents}", docs)
    # print(local_prompt)
    questions = [q.strip() for q in make_llm_call(sys_message, local_prompt, model) if q.strip()]
    return (questions, docs, topic)

# %%
sys_message = """I'm building a dataset of representative questions that a website visitor might ask. 
We're using our documents to build a set of "topics keywords" that represent our documents. 
I will provide a topic and the text for the document, your task is to generate a question 
that a user might ask, related to that topic, that may find its answer in our document. 
Make the question as human as possible and keep it short and not too specific, even if it's not comprehensive, 
as the users don't like to type a lot. 
It is important to keep the questions centered around the given topic keywords. 
Don't generate questions that are really specific to a place or project.
Generate maximum 5 questions. 
The answer should be simple text, no introduction, just one question per line. 
Don't use dashes at the beginning of lines. 
On the last line, extract a topic that summarizes the provided keywords, in the format: Topic: <topic>
"""

#Don't generate questions that are really specific to a place or project.

# %%
model = "meta-llama/Meta-Llama-3.1-70B-Instruct-Turbo"
dataset = []

for topic_id in topic_model.topic_representations_.keys():
    questions, docs, topic_keywords = get_questions(topic_model, topic_id, sys_message, model)
    qs = []
    for line in questions:
        if line.startswith("Topic: "):
            topic = line.replace("Topic: ", "")
        else:
            qs.append(line)
    record = {"keywords": topic_keywords, "questions": qs, "topic": topic}
    dataset.append(record)
    print("Topic id: %s" % topic_id)
    print("Topic keywords: %s" % topic_keywords)
    print("Topic: %s" % topic)
    
    for q in qs:
        print(q)
    print("\n")
# Out:
# Topic id: -1
# Topic keywords: copernicus, sentinel, monitoring, cookies, climate, monitor, earth, european, slovenian, temperature
# Topic: Earth Monitoring
# What is the Copernicus program monitoring?
# How does the Sentinel-3 satellite measure land-surface temperature?
# What is the purpose of the Copernicus Services?
# How does the European Union use cookies on its websites?
# What climate variables does the Copernicus Sentinel-3 satellite track?
#
#
# Topic id: 0
# Topic keywords: koje, praćenje, poskytuje, spremljanje, oceana, upravljanje, oceanu, oceánů, oceánu, razvoja
# Topic: Praćenje oceana
# Kako se praćenje oceana koristi za predviđanje stanja mora?
# Što je asimilacija podataka u kontekstu praćenja oceana?
# Kako se koriste sateliti za praćenje oceana?
# Što su indikatori praćenja oceana i kako se koriste?
# Kako se praćenje oceana koristi za podršku politikama EU-a?
#
#
# Topic id: 1
# Topic keywords: замърсяването, център, състоянието, замърсяване, свързани, вълни, със, например, променливи, морския
# Topic: Морско замърсяване
# Какво е замърсяването на морето и как се наблюдава?
# Какви са основните фактори, които влияят на състоянието на морето?
# Какви са последиците от замърсяването на морето за аквакултурите?
# Какви данни се използват за наблюдение и прогнозиране на морските вълни?
# Какви са основните изисквания за подобряване на системите за наблюдение на морето?
#
#
# Topic id: 2
# Topic keywords: taħt, baħar, oħra, għan, bħal, bħala, għal, jistgħu, għall, tagħna
# Topic: Monitoraġġ tal-Oċean
# Kif qed jiżviluppa s-servizz tal-monitoraġġ tal-oċeani?
# X'kapaċitajiet ġodda qed jiżviluppaw għall-monitoraġġ tal-baħar?
# Kif qed jiġu pprovduti l-indikaturi tal-monitoraġġ tal-oċean?
# X'informazzjoni qed tiġi pprovduta dwar l-istat tal-oċean?
# Kif qed jiġu analizzati l-prodotti CMEMS għal monitoraġġ aħjar tal-ambjent tal-baħar?
#
#
# Topic id: 3
# Topic keywords: επιφάνειας, θερμοκρασίας, περιοχές, περιπτώσεις, επιφάνεια, παρατηρήσεις, διαχείριση, στις, θερμοκρασία, πληροφορίες
# Topic: Θαλάσσια Βιοποικιλότητα
# Πώς επηρεάζει η θερμοκρασία την βιοποικιλότητα;
# Ποια είναι η σημασία της παρακολούθησης των παράκτιων υδάτων;
# Πώς μπορούν να χρησιμοποιηθούν οι ωκεάνιες πληροφορίες για τη διαχείριση των παράκτιων περιοχών;
# Ποιες είναι οι επιπτώσεις των περιβαλλοντικών αλλαγών στις θαλάσσιες περιοχές;
# Πώς συμβάλλει η επιτήρηση των υδάτων στη διατήρηση της βιοποικιλότητας;
#
#
# Topic id: 4
# Topic keywords: copernicus, volcano, eruption, sentinel, earth, eu, events, observation, slovenian, european
# Topic: Earth Observation
# What is the role of Copernicus in monitoring volcanic eruptions?
# How does the European Union use Earth observation data?
# What are the benefits of Copernicus for European citizens?
# How does Copernicus support disaster management and response?
# What kind of data does Copernicus provide for environmental monitoring?
#
#
# Topic id: 5
# Topic keywords: och, europæiske, europeiska, det, indikatorer, bæredygtig, kan, tjenester, eller, så
# Topic: Miljöövervakning och hållbarhet i Europa
# Hur kan europeiska miljöövervakningstjänster bidra till en mer hållbar framtid?
# Vilken roll spelar Copernicusprogrammet i övervakningen av jorden och klimatet?
# Hur kan data från kustvattenövervakning användas för att skydda biologisk mångfald?
# Vilka är de viktigaste indikatorerna för att mäta vattenkvalitet och biologisk mångfald i haven?
# Hur kan europeiska miljöinitiativ bidra till att uppnå en mer hållbar ekonomi?
#
#
# Topic id: 6
# Topic keywords: wildfires, fires, wildfire, emissions, arctic, siberia, fire, atmosphere, forecasts, weather
# Topic: Wildfires and their Environmental Impact
# What causes high carbon emissions from wildfires in the Arctic?
# How do wildfires in the Arctic affect the atmosphere?
# What is the impact of wildfires on the environment in Siberia?
# How do weather forecasts help track wildfires in the Arctic?
# What are the effects of wildfires on air quality in the Arctic region?
#
#
# Topic id: 7
# Topic keywords: óceánok, óceán, óceáni, szolgáltatások, szolgáltatás, kopernikusz, személyes, európai, szolgálat, erőforrások
# Topic: Óceánok irányítása és megfigyelése
# Milyen szerepet játszik az Európai Unió az óceánok irányításában?
# Milyen adatokat szolgáltat a Copernicus Tengeri Szolgálat?
# Mi az óceán digitális másolata?
# Milyen hatással van az éghajlatváltozás az óceánra?
# Milyen információkat nyújt a Copernicus Tengeri Szolgálat az óceán állapotáról?
#
#
# Topic id: 8
# Topic keywords: salinity, dataset, sea, wekeo, data, range, elevation, jupyterhub, map, measure
# Topic: Sea Water Salinity Data
# How do I access sea water salinity data on WEkEO?
# What is the elevation range for sea water salinity data on the map?
# How can I measure sea water salinity on the WEkEO platform?
# What is the time range for sea water salinity data available on WEkEO?
# How do I locate sea water salinity data on the WEkEO map?
#
#
# Topic id: 9
# Topic keywords: antarctic, arctic, antarctica, climate, seas, ice, sea, february, greenland, 2022
# Topic: Sea Ice and Climate Change
# What is the current state of Arctic sea ice cover?
# How does Antarctic sea ice extent compare to its average?
# What are the trends in Arctic sea ice concentration?
# Is the Arctic sea ice extent increasing or decreasing?
# How does climate change affect sea ice cover in the Arctic and Antarctic?
#
#
# Topic id: 10
# Topic keywords: atmospheric, pollution, ozone, atmosphere, emissions, aerosol, pollutants, weather, monitoring, emission
# Topic: Air Quality
# What are the effects of air pollution on human health?
# How is air quality monitored and forecasted?
# What tools are available to help policymakers manage air quality?
# How can individuals reduce their exposure to air pollution?
# What is the role of the Copernicus Atmosphere Monitoring Service in tackling air quality issues?
#
#
# Topic id: 11
# Topic keywords: wpływ, usługi, usług, działania, zarządzania, wykorzystywane, użytkownika, przybrzeżnych, że, ze
# Topic: Zarządzanie oceanami
# Jakie są korzyści z wykorzystania danych morskich w zarządzaniu oceanami?
# Jakie usługi oferuje Serwis monitorowania środowiska morskiego Copernicus?
# W jaki sposób dane morskie mogą przyczynić się do ochrony środowiska morskiego?
# Jakie są cele programu Copernicus w zakresie zarządzania oceanami?
# Jakie są korzyści z współpracy między Serwisem monitorowania środowiska morskiego Copernicus a EMODnet?
#
#
# Topic id: 12
# Topic keywords: ookeanide, ookeani, ookean, temperatuuri, kliimamuutuste, aaltojen, lainete, süsiniku, mõju, ovat
# Topic: Ookeani seisund ja kliimamuutused
# Mida mõjutab ookeani temperatuuri muutus?
# Kuidas ookeanid mõjutavad kliimamuutusi?
# Mida tähendab ookeani soojussisaldus?
# Kuidas ookeani seisund mõjutab ühiskonda?
# Mida on ookeani seisundi jälgimine?
#
#
# Topic id: 13
# Topic keywords: kliknite, croatian, finnish, swedish, slovenian, estonian, czech, slovak, politiky, koje
# Topic: Javne politike i zaštita okoliša
# Kako Evropska unija podržava zaštitu okoliša i razvoj gospodarstva?
# Koje su politike podržane od strane Copernicus Marine?
# Kako se spremači oceana mogu koristiti za podršku javnim politikama?
# Što je utjecaj onečišćenja mora plastikom na morsku faunu i ljude?
# Kako se može smanjiti onečišćenje mora plastikom?
#
#
# Topic id: 14
# Topic keywords: ozeane, ozeans, ozean, auswirkungen, europäischen, meeresoberfläche, entwicklung, beobachtungen, zu, ressourcen
# Topic: Ozean-Governance
# Wie kann die Überwachung der Ozeane verbessert werden?
# Welche Rolle spielt der Copernicus Marine Service bei der Meerespolitik?
# Wie kann die nachhaltige Nutzung der Meeresressourcen erreicht werden?
# Was sind die Auswirkungen des Klimawandels auf die Ozeane?
# Wie kann die Gesundheit der Ozeane bewertet werden?
#
#
# Topic id: 15
# Topic keywords: european, copernicus, gdpr, estonian, slovenian, swedish, lithuanian, latvian, bulgarian, mailerlite
# Topic: Copernicus Data Protection
# What is the Copernicus project's data sharing policy?
# How does the European Commission regulate data sharing?
# What is MailerLite and how does it handle personal data?
# Is my data protected under the GDPR when using this platform?
# What languages are supported by the Copernicus platform?
#
#
# Topic id: 16
# Topic keywords: copernicus, eu, space, galileo, euspa, earth, european, future, horizon, technologies
# Topic: EU Space Programme and Technologies
# What is the role of EUSPA in promoting Copernicus user uptake and R&D funding?
# How does the EU Space Programme support the development of space technologies?
# What is the CASSINI Hackathons initiative and its goal?
# How does the EU Global Action on Space initiative promote collaboration between the EU and space actors worldwide?
# What is the main focus of the EU Space Week event?
#
#
# Topic id: 17
# Topic keywords: consultivo, trabalhamos, estratégia, estrategia, serviços, serviço, consultatif, científico, trabajamos, servicio
# Topic: Servicio de Vigilancia Marina Copernicus
# ¿Cómo funciona el Servicio de Vigilancia Marina Copernicus?
# ¿Cuál es la estrategia de evolución del servicio de CMEMS?
# ¿Qué tipo de información proporciona el Servicio de Vigilancia Marina Copernicus?
# ¿Cómo se desarrollan los proyectos de I+D en CMEMS?
# ¿Qué es el Programa Copernicus y cómo se relaciona con CMEMS?
#
#
# Topic id: 18
# Topic keywords: europese, ecosystemen, oceanen, persoonlijke, verschillende, monitoren, indicatoren, ontwikkeling, kustgebieden, belangrijke
# Topic: Oceanen en Kustgebieden
# Hoe kan ik de gezondheid van de oceaan monitoren?
# Wat is de rol van de Europese Unie in het beschermen van de oceanen?
# Hoe kan ik bijdragen aan een duurzame toekomst voor de oceanen?
# Wat zijn de belangrijkste indicatoren voor de ontwikkeling van kustgebieden?
# Hoe kan ik toegang krijgen tot mariene gegevens en informatie?
#
#
# Topic id: 19
# Topic keywords: océanos, oceanos, oceanului, océano, oceano, oceanul, oceani, carbonio, oceaniche, carbono
# Topic: Riscaldamento degli oceani
# Come si misura il calentamento degli oceani?
# Qual è l'impatto dell'assorbimento di carbonio da parte degli oceani?
# Come cambia il livello del mare a causa del riscaldamento degli oceani?
# Quali sono gli effetti del riscaldamento degli oceani sulla biodiversità?
# Come si può ridurre l'impatto del riscaldamento degli oceani?
#
#
# Topic id: 20
# Topic keywords: copernicus, climate, ecmwf, cop26, cop28, atmosphere, forecasts, weather, c3s, unfccc
# Topic: Copernicus and Climate Action
# What role does Copernicus play in supporting climate action?
# How do Copernicus services contribute to climate adaptation efforts?
# What data does Copernicus provide to support policy-making on climate change?
# How does Copernicus support the monitoring of greenhouse gas emissions?
# What is the significance of Copernicus' participation in COP28?
#
#
# Topic id: 21
# Topic keywords: lietotāju, produktai, informacijos, įsipareigojimai, produkti, licencija, produktus, veikla, monitoringa, marine
# Topic: Jūrų duomenys ir paslaugos
# Kas yra EMODnet ir Copernicus Marine Service?
# Kokie duomenys teikiami per EMODnet ir Copernicus Marine Service?
# Kas yra jūrų duomenų pasiūlymo skirtumai ir papildymai tarp EMODnet ir Copernicus Marine Service?
# Kokie moksliniai tyrimai atliekami per EMODnet ir Copernicus Marine Service?
# Kas yra Europos Komisijos vaidmuo jūrų duomenų teikime?
#
#
# Topic id: 22
# Topic keywords: copernicuse, marine, käyttötapaukset, euroopa, euroopan, meripalvelun, jotta, käyttää, käytetään, tietojen
# Topic: Copernicus meripalvelu
# Miten Copernicus meripalvelu toimii?
# Mitä tietoa Copernicus meripalvelu tarjoaa?
# Miten voin käyttää Copernicus meripalvelun tuotteita?
# Mitä tarkoittaa Copernicus meripalvelun tuote?
# Miten Copernicus meripalvelu edistää merenhavainnointia Euroopassa?
#
#
# Topic id: 23
# Topic keywords: copernicus, ocean, coastal, volcano, sentinel, marine, eruption, portugal, eusso, mount
# Topic: Copernicus Oceanography
# What is the Copernicus program's role in monitoring ocean temperatures?
# How do satellite images help track volcanic eruptions?
# What data does the Copernicus Marine Service provide for ocean conditions?
# How does the EUSSO support satellite oceanography?
# What is the purpose of the Operational Satellite Oceanography Symposium?
#
#
# Topic id: 24
# Topic keywords: oceanos, océanos, océano, oceano, estrategia, estratégia, servicios, servicio, serviços, usuarios
# Topic: Océanos y Servicios Marítimos
# ¿Cómo se monitorean los cambios en los océanos?
# ¿Qué información proporciona el Servicio Marino Copernicus para la toma de decisiones?
# ¿Cuál es el papel del Servicio Marino Copernicus en la conservación del medio ambiente?
# ¿Qué datos se utilizan para evaluar la salud de los océanos?
# ¿Cómo se utilizan los datos oceanográficos operativos en la Economía Azul?
#
#
# Topic id: 25
# Topic keywords: precipitation, rainfall, humidity, moisture, hydrological, balkans, temperature, scandinavia, europe, soil
# Topic: European Climate Patterns
# What are the typical precipitation patterns in Europe during summer?
# How does soil moisture affect the climate in different regions of Europe?
# What are the effects of drought on European regions?
# How does relative humidity impact precipitation in Europe?
# What are the common weather patterns in the Balkans during the summer months?
#
#
# Topic id: 26
# Topic keywords: copernicus, cookies, preferences, slovenian, estonian, français, lithuanian, greek, accept, croatian
# Topic: Copernicus Website Settings
# How do I change the language on the Copernicus website?
# What languages are available on the Copernicus platform?
# How do I save my language preferences on Copernicus?
# Can I change my cookie preferences on the Copernicus website?
# How do I accept cookies on the Copernicus site?
#
#
# Topic id: 27
# Topic keywords: copernicus_sentinel_license, sentinel, copernicus, copernicus_land_monitoring_service_data_policy, copernicus_general_license, sentinels, eumetsat_copernicus_data_licence, copernicus_dem_instance_cop, copernicus_marine_service_product_license, copernicus_ecmwf_license
# Topic: Copernicus Data License
# What is the license for using Copernicus Sentinel data?
# Can I use Copernicus data for commercial purposes?
# What are the terms of the Copernicus General License?
# How do I access Copernicus Sentinel data?
# What are the usage rights for Copernicus Marine Service products?
#
#
# Topic id: 28
# Topic keywords: océanos, oceanos, océano, oceano, oceanul, oceani, oceanografia, estado, como, oceanelor
# Topic: Estado de los Océanos
# ¿Cómo ha cambiado el estado de los océanos en las últimas décadas?
# ¿Qué información proporciona el Informe sobre el Estado de los Océanos?
# ¿Cuáles son los cambios en el medioambiente marino en los últimos años?
# ¿Qué instituciones participan en la creación del Informe sobre el Estado de los Océanos?
# ¿Qué tipo de datos se utilizan para monitorear el estado de los océanos?
#
#
# Topic id: 29
# Topic keywords: πλαστική, πολιτικές, greek, πληροφορίες, ποιους, γαλάζιες, κλείστε, απαιτήσεις, χρήστες, αγορές
# Topic: Θαλάσσια Υπηρεσία Copernicus
# Τι είναι το Copernicus Marine Service;
# Ποια είναι οι απαιτήσεις παρατήρησης του CMEMS;
# Ποιους στόχους έχει η εκστρατεία #CMEMSforH2020;
# Ποια είναι η στρατηγική εξέλιξης υπηρεσιών του CMEMS;
# Ποια είναι τα έργα Ε&Α του CMEMS;
#
#
# Topic id: 30
# Topic keywords: ookeanide, ookeani, ookean, estonian, finnish, sektoriui, swedish, lithuanian, latvian, kasutusjuhtumid
# Topic: Ookeanide seisund
# Mida hõlmab roheline ookean?
# Mida tähendab valge ookean?
# Kuidas mõõdetakse ookeani seisundit?
# Mida on sinine ookean?
# Mida on ookeani seire?
#
#
# Topic id: 31
# Topic keywords: sentinel, satellites, satellite, esa, radar, volcano, eruption, imagery, monitor, mount
# Topic: Satellite Imagery and Monitoring
# What is the purpose of the Sentinel satellites?
# How do satellites monitor volcanic eruptions?
# What kind of data do Sentinel satellites provide?
# Can satellites track changes in sea level?
# How do radar altimeters contribute to oceanography?
#
#
# Topic id: 32
# Topic keywords: massimili, 3dvarbio, biogeoquímicos, assimilation, 3dvar, cmems, bio, bgc, modelo, 1016
# Topic: Biogeochemical Data Assimilation
# What is the impact of BGC-Argo data assimilation on biogeochemistry?
# How does the 3DVarBio method improve the description of vertical structure in biogeochemical models?
# What are the benefits of using a multi-data assimilation framework for BGC-Argo float and Satellite observations?
# How does the MASSIMILI project contribute to the improvement of CMEMS biogeochemical products?
# What is the role of observation error in controlling the effectiveness of data assimilation in biogeochemical models?
#
#
# Topic id: 33
# Topic keywords: център, коперник, замърсяване, морски, български, затвори, за, заинтересовани, изисквания, морските
# Topic: Морска служба "Коперник"
# Какво е Морска служба "Коперник"?
# Как се произвеждат данните на Морска служба "Коперник"?
# Кой е целевата група на Морска служба "Коперник"?
# Каква е целта на Морска служба "Коперник"?
# Кой е заинтересован от услугите на Морска служба "Коперник"?
#
#
# Topic id: 34
# Topic keywords: oceano, modelos, modelo, como, wave2nemo, projeto, observações, modello, resultado, olas
# Topic: Modelos de olas oceánicas
# ¿Cómo se pueden mejorar los modelos de olas para predecir mejor las olas extremas en el mar?
# ¿Qué es el proyecto Wave2NEMO y cómo mejora la previsión de olas oceánicas?
# ¿Cómo se pueden utilizar los modelos de circulación oceánica y los modelos de olas para mejorar la previsión del oleaje?
# ¿Qué es el proyecto WaveFlow y cómo afecta la circulación en la parte superior del océano?
# ¿Cómo se pueden validar los modelos de olas utilizando datos de satélite y plataformas in situ?
#
#
# Topic id: 35
# Topic keywords: precipitation, snowfall, snow, rain, forecasting, runoff, clouds, evaporation, ensemble, accumulation
# Topic: Precipitation and Snowfall Data
# What is the average snowfall in a given area over a certain period of time?
# How is large-scale precipitation fraction calculated in ERA5 data?
# What is the difference between large-scale snowfall and convective snowfall?
# How is snow evaporation measured in ERA5 post-processed daily statistics?
# What is the relationship between precipitation and runoff in a given area?
#
#
# Topic id: 36
# Topic keywords: okeāna, okeānā, ekosistēmas, piekrastes, ilgtspējīgas, sasilšana, izraisa, okeānu, lietošanas, akvakultūras
# Topic: Okeāna stāvoklis un klimata pārmaiņas
# Kā okeāna sasilšana ietekmē jūras līmeni?
# Kā okeāns absorbē un izdala siltumu?
# Kā klimata pārmaiņas ietekmē okeāna stāvokli?
# Kā okeāna paskābināšanās ietekmē organismus?
# Kā okeāna siltuma satura tendence mainās laika gaitā?
#
#
# Topic id: 37
# Topic keywords: gdpr, analytics, privacy, cookies, mailerlite, email, european, newsletter, twitter, https
# Topic: GDPR and Cookie Policy
# What cookies do you use on your website?
# How do you protect my personal data when I sign up for your newsletter?
# Do you share my website interactions with third parties?
# What analytics system do you use to monitor website interactions?
# How do you ensure GDPR compliance for email marketing?
#
#
# Topic id: 38
# Topic keywords: baħar, għall, għal, agħlaq, sħana, naħdmu, tagħna, għarfien, aħbarijiet, oċeani
# Topic: Baħar
# X'informazzjoni jipprovdi s-Servizz tal-Baħar Copernicus?
# Kif jiġi monitorat l-oċean?
# X'inhu l-Oċean Blu?
# Kif jiġi użat il-programm H2020 għall-proġetti tal-baħar?
# X'vantaġġi jipprovdi s-Servizz tal-Baħar Copernicus għall-proġetti tal-baħar?
#
#
# Topic id: 39
# Topic keywords: gdpr, mailerlite, copernicus, cookies, email, newsletter, european, privacy, twitter, slovenian
# Topic: GDPR and Email Marketing
# What is the purpose of functional cookies on a website?
# How does a website manage personal data for newsletter sign-ups?
# What is GDPR compliance in email marketing?
# How do I withdraw consent for cookies on a website?
# What is a GDPR-compliant European email marketing platform?
#
#
# Topic id: 40
# Topic keywords: gdpr, analytics, privacy, cookies, monitor, cookie, anonymised, email, https, mailerlite
# Topic: Website Privacy and Cookies Policy
# What kind of cookies do you use on your website?
# How do you protect user data and ensure GDPR compliance?
# Do you share my personal data with third-party services?
# What kind of information do you collect through analytics?
# How do you use cookies to enhance user experience?
#
#
# Topic id: 41
# Topic keywords: copernicus, climate, volcano, eruption, emissions, european, co2, portugal, indonesia, events
# Topic: Climate Change and European Union Initiatives
# How does the European Union use science to tackle climate change?
# What are the effects of volcanic eruptions on climate change?
# How does the Copernicus program help with climate action?
# What information is available to help adapt to climate change?
# How does the European Union support climate change research and development?
#
#
# Topic id: 42
# Topic keywords: hydrological, climate, drought, forecasts, meteorological, forecast, rainfall, floods, flooding, hydropower
# Topic: Hydrological Climate Management
# How can climate forecasts help manage water supply?
# What are the effects of climate change on river discharge?
# How can hydrological seasonal forecasts support water management?
# What are the potential impacts of climate change on hydropower systems?
# How can climate data help predict flooding and droughts?
#
#
# Topic id: 43
# Topic keywords: ozone, stratosphere, antarctic, atmosphere, stratospheric, antarctica, ultraviolet, sun, arctic, ecmwf
# Topic: Ozone Layer
# What causes the ozone hole over Antarctica?
# How does the ozone layer protect life on Earth?
# What is the relationship between temperature and ozone depletion?
# How is the ozone hole area calculated?
# What is the role of polar stratospheric clouds in ozone depletion?
#
#
# Topic id: 44
# Topic keywords: wave, wavewatch, waveflow, wave2nemo, mywave, projektu, projekta, modeļa, modela, modelio
# Topic: Wave Modeling
# What are the main differences between WAVEWATCH III and WAM models?
# How do you calculate maximum wave height in WAM?
# What is the purpose of the LATEMAR project in CMEMS?
# How do you evaluate extreme wave distribution functions in marine environments?
# What are the key results of the LATEMAR program in terms of wave modeling?
#
#
# Topic id: 45
# Topic keywords: microplastics, microplastic, plastics, pollution, oceans, debris, plastic, sea, marine, ocean
# Topic: Marine Plastic Pollution
# What are the main sources of marine plastic pollution?
# How does plastic waste enter the ocean?
# What are the effects of plastic pollution on marine ecosystems?
# How can we reduce plastic pollution in the ocean?
# What initiatives are being taken to combat marine plastic pollution?
#
#
# Topic id: 46
# Topic keywords: pieeja, lithuanian, informuotumas, piesārņojums, latvian, plastmasas, skaidrotāji, lietotāju, aiškintojai, politika
# Topic: Plastiko tarša jūrose
# Kas yra plastiko tarša ir kaip ji veikia jūrų fauną?
# Kokį poveikį daro plastmasos piesārņojums žmonėms?
# Kas yra plastiko tarša okeane?
# Kaip galima sumažinti plastiko taršą jūrose?
# Kas yra plastmasas piesārņojums okeānā?
#
#
# Topic id: 47
# Topic keywords: mercator, volcano, repository, eruption, portugal, slovenian, swedish, eusso, laki, portuguese
# Topic: Ocean Monitoring
# What is the Mercator Ocean repository?
# How does the EUSSO support ocean monitoring?
# What kind of data can I find in the Mercator Ocean repository?
# How does the Copernicus Marine Service monitor oil spills?
# What kind of information can I find on the Copernicus website?
#
#
# Topic id: 48
# Topic keywords: climate, c3s, datasets, ecmwf, data, europa, ecv, software, catalogue, eqc
# Topic: Climate Data Store
# What is the Climate Data Store and what does it offer?
# How does the Climate Data Store ensure the quality of its datasets?
# What kind of data can I find in the Climate Data Store?
# How can I access and manipulate climate data in the Climate Data Store?
# What tools are available in the Climate Data Store for analyzing and predicting climate change impacts?
#
#
# Topic id: 49
# Topic keywords: humidity, climate, precipitation, moisture, annual, soil, copernicus, temperature, 2024, 2021
# Topic: Climate and Precipitation Patterns
# What is the average annual precipitation in Europe?
# How does relative humidity affect soil moisture?
# What is the relationship between temperature and precipitation?
# How does climate change impact soil moisture levels?
# What are the average annual temperature and precipitation levels in Europe?
#
#
# Topic id: 50
# Topic keywords: aquaculture, fisheries, fishery, fish, shellfish, fishing, sea, jellyfish, aquatic, marine
# Topic: Aquaculture Management
# What are the main challenges in aquaculture management?
# How does eutrophication affect aquaculture farms?
# What are Harmful Algal Blooms and how do they impact aquaculture?
# How can aquaculture farms reduce their environmental impact?
# What tools are available to support sustainable aquaculture practices?
#
#
# Topic id: 51
# Topic keywords: co2, co₂, emissions, methane, greenhouse, carbon, atmosphere, gases, atmospheric, dioxide
# Topic: Greenhouse Gases
# What are the main greenhouse gases emitted by human activities?
# How do human activities lead to the emission of greenhouse gases?
# What is the current trend in atmospheric concentrations of carbon dioxide and methane?
# How are greenhouse gas fluxes estimated and measured?
# What are the main sources and sinks of carbon dioxide emissions?
#
#
# Topic id: 52
# Topic keywords: oceanography, oceanpredict, ocean, seas, coastal, biogeosciences, biogeochemical, scientist, sciences, prediction
# Topic: Oceanography and Ocean Prediction
# What is oceanography and how does it relate to climate change?
# How do scientists predict ocean currents and tides?
# What is the role of biogeochemical modeling in oceanography?
# How do researchers study the impact of human activities on the marine environment?
# What is the importance of ocean data assimilation in predicting ocean behavior?
#
#
# Topic id: 53
# Topic keywords: downloading, downloads, dataset, download, datasets, customise, package, file, packaged, redownload
# Topic: Downloading Datasets
# How do I customize my dataset downloads?
# Can I download multiple datasets at once?
# How do I change the format of my downloaded data?
# Can I pause a download that is in progress?
# How do I access my previous downloads?
#
#
# Topic id: 54
# Topic keywords: salinity, global_analysis_forecast_bio_001_028, global_analysis_forecast_phy_001_024, lambda, pcoms, projekta, projektu, projekt, 06o, sāļuma
# Topic: Salinity Modeling and Prediction
# How does salinity affect water quality in surrounding waters?
# What is the impact of extreme events on sea surface salinity?
# How do different models compare in predicting salinity levels?
# What is the relationship between river discharge and sea surface salinity?
# How accurate are LAMBDA modeling scenarios in reproducing salinity events?
#
#
# Topic id: 55
# Topic keywords: χρήστες, χρησιμοποιούνται, περιπτώσεις, δείκτες, υπηρεσίας, πολιτικών, δραστηριότητες, δεσμεύσεις, στις, έως
# Topic: Θαλάσσια Υπηρεσίες και Δεδομένα
# Ποιες υπηρεσίες προσφέρει το Copernicus Marine Service;
# Πώς μπορούν οι χρήστες να επωφεληθούν από τα δωρεάν θαλάσσια δεδομένα;
# Ποιες είναι οι δραστηριότητες του EU4Oceanobs;
# Πώς χρησιμοποιούνται οι δείκτες για την υποστήριξη των πολιτικών της ΕΕ;
# Ποιες περιπτώσεις χρήσης υπάρχουν για την παρακολούθηση παράκτιων υδάτων;
#
#
# Topic id: 56
# Topic keywords: copernicus, oceanpredict, ocean, marine, forecasting, cmems_eu, cmems, upcoming, 2024, symposium
# Topic: Ocean Forecasting and Monitoring
# What is the Copernicus Marine Service and what does it offer?
# How can I stay updated on upcoming ocean forecasting events and workshops?
# What is the OceanPredict Symposium and when is it taking place?
# How does Copernicus contribute to ocean monitoring and management?
# What are the latest developments in ocean forecasting and prediction?
#
#
# Topic id: 57
# Topic keywords: plastföroreningar, swedish, och, tillvägagångssätt, plastikforurening, användningsfall, politikker, brugerdrevet, samfundsmæssig, kan
# Topic: Plastföroreningar
# Vad är plastföroreningar i havet?
# Hur kan vi minska plastföroreningar i havet?
# Vilka verktyg finns för att bekämpa plastföroreningar?
# Hur påverkar plastföroreningar miljön och samhället?
# Vad kan vi göra för att minska plastskräp i havet?
#
#
# Topic id: 58
# Topic keywords: precipitation, rainfall, humidity, moisture, soil, eastern, extratropical, hemisphere, february, asia
# Topic: Precipitation and Soil Moisture Patterns
# What are the current trends in precipitation and soil moisture globally?
# How does relative humidity affect soil moisture levels?
# What are the typical humidity levels in the extratropical hemisphere?
# How does precipitation vary across different regions of Asia?
# What are the average conditions of precipitation and soil moisture in the eastern hemisphere?
#
#
# Topic id: 59
# Topic keywords: copernicus, privacy, estonian, cookies, mailerlite, slovenian, https, lithuanian, français, swedish
# Topic: Copernicus Website Settings
# What is the language selection for the Copernicus website?
# How does Copernicus handle user cookies and data?
# What is the privacy policy for the Copernicus website?
# Can I change my language preferences on the Copernicus site?
# Is the Copernicus website available in multiple languages?
#
#
# Topic id: 60
# Topic keywords: mailerlite, gdpr, copernicus, email, european, data, privacy, slovenian, estonian, swedish
# Topic: Copernicus Data Management
# What email marketing platform does Copernicus use for managing personal data?
# Is MailerLite GDPR compliant?
# How does Copernicus manage personal data from European users?
# What languages are supported by Copernicus for data management?
# Is MailerLite used for managing data in multiple European languages?
#
#
# Topic id: 61
# Topic keywords: copernicus, climate, solar, renewables, renewable, forecasts, energy, ecmwf, c3s, europe
# Topic: Climate and Renewable Energy
# How does climate data support the development of renewable energy sources?
# What role does the Copernicus Climate Change Service play in the European energy sector?
# How can climate forecasts help energy suppliers prepare for seasonal changes?
# What kind of climate information is available for the energy sector in Europe?
# How does climate data impact decision-making in the energy industry?
#
#
# Topic id: 62
# Topic keywords: oceannews, antarctic, arctic, ocean, warming, oceanenergy, sea, temperature, heatwaves, marine
# Topic: Ocean Warming
# What's happening to the ocean's temperature?
# Is the Arctic sea ice melting?
# How is the ocean's heat content changing?
# What's causing the increase in marine heatwaves?
# Is the sea level rising?
#
#
# Topic id: 63
# Topic keywords: ensemble, ensembles, multicast, multigrid, multigrille, ranked, grids, top2, agrif, top
# Topic: Multigrid Ensemble Data Assimilation
# What is the impact of multigrid EnKF analysis on forecast skill?
# How does multigrid data assimilation improve ensemble performance?
# What is the effect of 2-way nesting with AGRIF on ensemble forecasting?
# How does the multigrid version of SDAP improve ensemble analysis?
# What are the benefits of using multigrid covariances in ensemble forecasting?
#
#
# Topic id: 64
# Topic keywords: dust, atmospheric, atmosphere, aerosol, weather, sahara, saharan, skies, mediterranean, desert
# Topic: Desert Dust
# What is desert dust and how does it affect the atmosphere?
# How far can dust travel through the air?
# Can dust transport pose a risk to human health?
# What kind of pollutants can be carried by desert dust?
# How is desert dust monitored and forecasted?
#
#
# Topic id: 65
# Topic keywords: oceanului, oceanul, oceani, coastă, marine, serviciului, serviciul, climatice, servicii, oceanelor
# Topic: Oceanografie și protecția mediului marin
# Cum pot fi utilizate datele oceanografice pentru a proteja mediul marin?
# Care sunt beneficiile utilizării serviciilor de monitorizare a oceanelor?
# Cum pot fi gestionate resursele marine într-un mod durabil?
# Ce rol joacă serviciile de informare ale programului Copernicus în monitorizarea apelor de coastă?
# Cum pot fi utilizate datele oceanografice pentru a combate schimbările climatice?
#
#
# Topic id: 66
# Topic keywords: glaciers, glacier, greenland, antarctic, iceberg, antarctica, icebergs, ice, sentinel, volcano
# Topic: Glaciers and Ice Monitoring
# What is happening to the ice in Greenland?
# How do satellites track glacier changes?
# What role does Sentinel play in monitoring icebergs?
# How fast are Greenland's glaciers moving?
# What is the impact of climate change on Antarctic ice?
#
#
# Topic id: 67
# Topic keywords: copernicus, italy, alps, sentinel, volcano, satellite, eruption, esa, lake, portugal
# Topic: Earth Observation
# What is the Copernicus program used for?
# How do satellites monitor volcanic eruptions?
# What is the role of Sentinel in Earth observation?
# Can satellite data be used to study lakes and their ecosystems?
# How does the European Space Agency use satellite imagery?
#
#
# Topic id: 68
# Topic keywords: wildfires, volcano, fires, wildfire, eruption, copernicus, forests, forest, firefighters, portugal
# Topic: Wildfires and Forest Fires
# What causes forest fires to spread quickly?
# How do firefighters respond to wildfires in Europe?
# What role does Copernicus play in monitoring forest fires?
# Can satellite imagery help track the spread of wildfires?
# How do volcanic eruptions affect nearby forests?
#
#
# Topic id: 69
# Topic keywords: climate, esotc, 2023, arctic, 2022, europe, 2021, greenhouse, temperatures, weather
# Topic: Climate Monitoring
# What is the current state of the climate in Europe?
# How does the Arctic climate compare to the rest of the world?
# What are the key findings of the European State of the Climate report?
# How do greenhouse gas emissions affect global temperatures?
# What are the main climate indicators used to monitor climate change?
#
#
# Topic id: 70
# Topic keywords: oceanography, seas, ocean, sea, seawater, marine, waters, indicators, monitoring, ecosystems
# Topic: Oceanography
# What is the current state of the ocean and its ecosystems?
# How is climate change affecting the ocean and its marine life?
# What are the key indicators used to monitor the health of the ocean?
# How does the ocean regulate the Earth's climate and sustain life?
# What are some of the changes observed in the ocean's physical and biogeochemical state?
#
#
# Topic id: 71
# Topic keywords: sentinel, sentinel2go, esa, monitor, matomo, analytics, cookies, volcano, server, eruption
# Topic: Copernicus Website and Data Analytics
# What is the purpose of cookies on the Copernicus website?
# How does the Copernicus website use Matomo analytics?
# What types of cookies are used on the Copernicus website?
# How does the Copernicus website monitor server access?
# What is the role of the European Space Agency in the Copernicus project?
#
#
# Topic id: 72
# Topic keywords: monitoring, updates, file, download, site, ft, guides, manual, factsheet, validation
# Topic: Land Monitoring
# How do I download validation reports from the site?
# What kind of guides are available for land monitoring?
# Where can I find updates on land monitoring services?
# How do I access technical assistance for land monitoring?
# What kind of files can I download from the site?
#
#
# Topic id: 73
# Topic keywords: baltic, sea, mediterranean, ocean, salinity, trend, anomaly, 2022, temperature, reanalysis
# Topic: Baltic Sea Surface Temperature
# What is the trend of Baltic Sea surface temperature anomalies?
# How does the Baltic Sea surface temperature compare to the Mediterranean?
# What is the salinity trend in the Baltic Sea?
# Is the Baltic Sea surface temperature increasing or decreasing?
# What is the current temperature anomaly in the Baltic Sea?
#
#
# Topic id: 74
# Topic keywords: analytics, cookies, gdpr, privacy, monitor, cookie, https, server, security, platform
# Topic: Website Data Protection and Security
# What kind of cookies do you use on your website?
# How do you ensure the security of my data on your platform?
# What is your policy on data sharing with third-party contractors?
# Do you comply with the GDPR regulations for data protection?
# How do you use analytics to improve your services?
#
#
# Topic id: 75
# Topic keywords: vegetation, leaf, biomes, canopy, raster, 1km, ndvi, reflectances, km, greenness
# Topic: Vegetation Monitoring
# What is the Leaf Area Index and how is it measured?
# How does the Normalised Difference Vegetation Index relate to the greenness of biomes?
# What is the Fraction of Green Vegetation Cover and how is it quantified?
# How often are global vegetation estimates available and at what spatial resolution?
# What is the difference between Leaf Area Index versions 1 and 2?
#
#
# Topic id: 76
# Topic keywords: temperatures, temperature, summer, seasonal, winter, summers, warmer, daytime, daytimes, europe
# Topic: Seasonal Temperature Trends
# Is Europe experiencing more heat stress during summers?
# How does the Universal Thermal Climate Index measure heat stress?
# What is the trend in heat stress levels in northern Europe during summers?
# Are winters in Europe getting colder or warmer?
# Is heat stress increasing in southern Europe during summers?
#
#
# Topic id: 77
# Topic keywords: snow, sar, snowfinch, sentinel, classified, fsc, resolution, sensing, metadata, raster
# Topic: Snow Cover Remote Sensing
# What data is used to validate snow cover products?
# How is wet snow detected in remote sensing data?
# What is the difference between wet and dry snow in remote sensing?
# How is fractional snow cover data validated?
# What data sources are used to create high-resolution snow cover maps?
#
#
# Topic id: 78
# Topic keywords: humidity, precipitation, moisture, hydrological, seasonal, drying, soil, temperature, europe, southern
# Topic: European Climate and Hydrology
# Is Europe experiencing a decline in relative humidity over time?
# How does temperature affect soil moisture in different regions?
# What is the relationship between precipitation and relative humidity in Europe?
# Is there a seasonal pattern to the drying detected in European regions?
# How do regional differences in Europe impact hydrological variables and temperature?
#
#
# Topic id: 79
# Topic keywords: zahtjevi, opazovanje, surađujemo, razvoja, razvojni, okolje, evolucije, sprejemanja, raziskovalno, savjetodavni
# Topic: Razvoj morskog okolja
# Kako se razvija morsko okolje?
# Kako se sprejemaju novi zahtjevi za opazovanje?
# Kako se razvijaju raziskovalno-razvojni projekti?
# Kako se izvaja strategija evolucije usluge?
# Kako se surađuje s korisnicima?
#
#
# Topic id: 80
# Topic keywords: monitorizarea, nws, modelis, monitorización, monitorização, nrt, modelo, modèle, modell, model
# Topic: Monitorizarea și prognoză
# What is the North West Shelf Monitoring Forecasting Center?
# How does the NWS MFC provide real-time monitoring and forecasting?
# What kind of data does the NWS MFC use for its models?
# What are some of the applications of the NWS MFC's monitoring and forecasting services?
# What kind of support does the NWS MFC offer to industries such as aquaculture and fishing?
#
#
# Topic id: 81
# Topic keywords: floods, flood, flooded, flooding, eruption, copernicus, volcano, disaster, emergency, rains
# Topic: Natural Disasters and Emergency Response
# What happens when a volcano erupts and causes flooding?
# How does Copernicus help in emergency situations like floods?
# What kind of maps does Copernicus provide during flood emergencies?
# How does heavy rainfall affect areas prone to flooding?
# What is the role of Copernicus in disaster management?
#
#
# Topic id: 82
# Topic keywords: groundwater, freshwater, catchment, basin, water, basins, volcano, irrigation, environmental, inland
# Topic: Water Management
# How can satellite data help manage water resources?
# What is the role of Copernicus in monitoring inland water bodies?
# How can water bodies be mapped and monitored?
# What are the benefits of using satellite data for water management?
# How can environmental monitoring support sustainable water use?
#
#
# Topic id: 83
# Topic keywords: mediterranean, sea, maritime, spill, oil, riskaware, vessel, ocean, malta, spills
# Topic: Oil Spill Monitoring
# What are the risks of oil spills in the Mediterranean Sea?
# How can oil spills be monitored in the ocean?
# What are the consequences of oil spills for the environment?
# How can maritime traffic be managed to reduce oil spill risks?
# What tools are available for predicting oil spill drift?
#
#
# Topic id: 84
# Topic keywords: océaniques, océans, océan, marines, maritimes, climatique, politiques, marins, environnement, européenne
# Topic: Politiques et gestion des océans
# Quel est le rôle de l'Union européenne dans la protection des océans ?
# Comment les données océanographiques peuvent-elles aider à lutter contre le changement climatique ?
# Quels sont les objectifs du programme Copernicus pour l'océanographie ?
# Comment les politiques marines de l'UE contribuent-elles à la conservation de l'environnement ?
# Quel est l'impact de la pollution plastique sur les océans ?
#
#
# Topic id: 85
# Topic keywords: cmems, search, estonian, scrum2, cnr, wavewatch, abstrakt, climsea, waveflow, cnrs
# Topic: Wave Modeling in CMEMS
# What is the purpose of the WAVEFLOW project in CMEMS?
# How does the CMEMS system model wave behavior during storms?
# What is the main goal of the LATEMAR project in improving wave modeling?
# Can CMEMS provide information on individual wave parameters?
# What are the benefits of using the WAVEFLOW model for ocean monitoring?
#
#
# Topic id: 86
# Topic keywords: copernicus, cmems_eu, marine, oceanpredict, ocean, mercator, monitoring, service, upcoming, forecasting
# Topic: Copernicus Marine Service
# What is the Copernicus Marine Environment Monitoring Service?
# How does the Copernicus Marine Service monitor the ocean?
# What are the main achievements of the Copernicus Marine Service in 2022?
# How does the Copernicus Marine Service use satellite and in-situ data?
# What are the future prospects of the Copernicus Marine Service?
#
#
# Topic id: 87
# Topic keywords: въпроси, замърсяването, свързани, европейския, събития, достъп, център, морския, коперник, морски
# Topic: Морска служба "Коперник"
# Какво е Морската служба "Коперник"?
# Какви данни предоставя Морската служба "Коперник"?
# Как се използват данните на Морската служба "Коперник" в политиките и управлението на океана?
# Каква е целта на Морската служба "Коперник" в сферата на наблюдение на Земята?
# Как се защитават личните данни в бюлетина на Морската служба "Коперник"?
#
#
# Topic id: 88
# Topic keywords: co2, co2m, emissions, co2mvs, carbon, greenhouse, methane, climate, atmospheric, atmosphere
# Topic: Climate Change and Greenhouse Gas Emissions
# How can we monitor greenhouse gas emissions effectively?
# What is the role of satellites in tracking carbon dioxide levels?
# How can we reduce anthropogenic carbon dioxide emissions?
# What is the impact of human activities on climate change?
# How can we track methane levels in the atmosphere?
#
#
# Topic id: 89
# Topic keywords: monitoring, copernicus, lake, lakes, temperature, guides, manual, download, version, site
# Topic: Lake Surface Water Temperature Monitoring
# How do I monitor lake surface water temperature?
# Where can I find guides for lake temperature monitoring?
# What is the latest version of the lake surface water temperature manual?
# Can I download the lake surface water temperature quality assessment report?
# How do I access lake temperature monitoring resources on the Copernicus site?
#
#
# Topic id: 90
# Topic keywords: sea, python, plotting, visualizing, wave, visualize, tutorial, biogeochemical, environment, maps
# Topic: Visualizing Ocean Data with Python
# How do I visualize sea ice products using Python?
# What is the best way to plot wave model products in the Arctic Ocean?
# Can I use Python to create maps of biogeochemical data in the ocean?
# How do I get started with visualizing ocean data using Python?
# What are some good resources for learning to visualize environmental data with Python?
#
#
# Topic id: 91
# Topic keywords: copernicusecmwf, copernicus, meteorological, copernicuseu, climate, ecmwf, eu, europe, forecasts, weather
# Topic: Copernicus and ECMWF
# What is the Copernicus programme and what does it do?
# How does the ECMWF contribute to weather forecasting in Europe?
# What is the role of the Copernicus Atmosphere Monitoring Service?
# How does the ECMWF support climate change research in Europe?
# What is the relationship between the ECMWF and the EU's Copernicus programme?
#
#
# Topic id: 92
# Topic keywords: lakes, lake, waters, observations, reflectances, reflectance, sensor, dataset, inland, water
# Topic: Lake Water Quality
# What is the spatial resolution of lake water quality data?
# How often are lake water quality observations updated?
# What sensor is used to collect lake water quality data?
# How can I access lake water quality data for a specific area?
# What is the temporal extent of the lake water quality dataset?
#
#
# Topic id: 93
# Topic keywords: habitats, habitat, ecological, ecosystem, landscape, biodiversity, urbanisation, forests, urban, cities
# Topic: Urban Ecology
# How can urban planners balance the need for connectivity with the need for isolation in habitats?
# What are the benefits of green wedges in urban areas?
# How can Urban Atlas data be used to improve access to green spaces in cities?
# What role do green spaces play in promoting biodiversity in urban environments?
# How can cities use data to design more liveable and sustainable environments?
#
#
# Topic id: 94
# Topic keywords: cookies, cookie, express, browser, tracking, settings, preferences, stored, store, disabled
# Topic: Cookies and Browser Tracking
# What are cookies and how do they work?
# How do I manage my cookie settings in my browser?
# What kind of information do cookies store on my device?
# Why do websites use tracking cookies?
# What happens if I disable cookies on a website?
#
#
# Topic id: 95
# Topic keywords: phytoplankton, chlorophyll, photosynthesis, biogeochemistry, ecosystem, biogeochemical, ecosystems, ocean, organisms, carbon
# Topic: Phytoplankton and Ocean Ecosystems
# What is the role of phytoplankton in the ocean's carbon cycle?
# How does chlorophyll-a concentration affect the ocean's ecosystem?
# What is the impact of climate change on phytoplankton growth?
# How do scientists use satellite data to monitor phytoplankton in the ocean?
# What is the relationship between phytoplankton and the ocean's oxygen levels?
#
#
# Topic id: 96
# Topic keywords: meteorological, era5, era5t, climate, atmospheric, weather, ecmwf, reanalysis, observations, dataset
# Topic: ERA5 Reanalysis Dataset
# What is the ERA5 reanalysis dataset used for?
# What is the difference between ERA5 and ERA5-Land datasets?
# How often is the ERA5 dataset updated?
# What is the resolution of the ERA5-Land dataset?
# What is the purpose of the ERA5-Land-T service?
#
#
# Topic id: 97
# Topic keywords: chlorophyll, ensembles, ensemble, odessa, spread, perturbing, perturbations, perturbados, radtrans, bgc
# Topic: Chlorophyll Ensemble Modeling
# What is the effect of perturbations on chlorophyll levels?
# How does ensemble spread relate to chlorophyll concentration?
# What happens to chlorophyll when model components are perturbed?
# How does perturbing aCDOM affect chlorophyll levels?
# What is the relationship between ensemble spread and chlorophyll variability?
#
#
# Topic id: 98
# Topic keywords: slovenian, monitor, european, analytics, cookies, gdpr, eusso, android, czech, lithuanian
# Topic: EU Copernicus Website
# What cookies are used on this website?
# How does the website use my data for analytics?
# What is the purpose of essential cookies on this site?
# How does the website ensure GDPR compliance?
# What languages are available on this website?
#
#
# Topic id: 99
# Topic keywords: disasters, copernicus, disaster, volcanic, eruption, volcano, crises, emergencies, landslide, crisis
# Topic: Disaster Management
# How can satellite imagery help in disaster management?
# What types of disasters can be supported by Copernicus Risk and Recovery Mapping?
# How does Copernicus Emergency Management Service support disaster risk reduction?
# What is the typical delivery time for Copernicus Risk and Recovery Mapping products?
# Can Copernicus Emergency Management Service support humanitarian crises?
#
#
# Topic id: 100
# Topic keywords: algorithm, guides, soil, document, temperature, basis, surface, site, land, vegetation
# Topic: Land Surface Temperature
# What is the basis for land surface temperature algorithms?
# How do I measure land surface temperature?
# What guides are available for land surface temperature algorithms?
# How does vegetation affect land surface temperature?
# What is the relationship between soil temperature and land surface temperature?
# ...
# Topic: Ocean and Maritime Data Applications
# What is the European Digital Twin Ocean?
# How is marine data used for maritime safety?
# What is the OceanPredict Symposium 2024 about?
# How can Copernicus marine data be used for coastal monitoring?
# What is the purpose of the OceanHack4EU hackathon?
#
#
# Topic id: 394
# Topic keywords: hive, cmems, scrum2, search, climsea, estonian, lmtl, metoffice, lithuanian, genoa
# Topic: High-Resolution Model Verification Evaluation
# What is the purpose of the HiVE project in relation to CMEMS forecast products?
# What is the High-Resolution Assessment framework used for in the HiVE project?
# What is the Continuous Ranked Probability Score used to measure in forecast verification?
# What is the main goal of the HiVE project in evaluating high-resolution ocean models?
# What is the role of the UK MetOffice in the HiVE project?
#
#
# Topic id: 395
# Topic keywords: massimili, cmems, gianpiero, spalvos, italiano, bio, heloise, mio, search, organizacija
# Topic: Ocean Monitoring and Data Assimilation
# What is the MASSIMILI project about?
# What is the goal of the MASSIMILI project in ocean monitoring?
# Who is the principal investigator of the MASSIMILI project?
# What is the role of Gianpiero Cossarini in the MASSIMILI project?
# What is the purpose of integrating Bio-Argo data with ocean color data in CMEMS-MFCs?
#
#
# Topic id: 396
# Topic keywords: offshorenavigation, voyopt, h2020, projetos, copernicus, marine, projektu, voyage, planeamento, cmemsforh2020
# Topic: Voyage Optimization and Marine Data
# What is the role of Copernicus Marine Service in H2020 projects?
# How can marine data be used for voyage optimization?
# What are some examples of H2020 projects that have benefited from Copernicus Marine data?
# How can marine data support the conservation of marine wildlife?
# What is the purpose of the VoyOpt system in offshore navigation?
#
#
# Topic id: 397
# Topic keywords: cosi, čoskoro, slovenian, co, czech, croatian, estonian, técnicas, lithuanian, slovak
# Topic: Calibration of Sea-Ice Forecasts
# What is the COSI project about?
# How does the COSI project improve sea-ice forecasts?
# What is the goal of the COSI project in terms of sea-ice concentration forecasts?
# What is the expected outcome of the COSI project for seafarers?
# How does the COSI project use machine learning algorithms?
#
#
# Topic id: 398
# Topic keywords: seaports, sea, coastal, oceanpredict, ocean, marine, forecasts, romanian, forecasting, navigation
# Topic: Ocean Forecasting and Navigation
# What are the benefits of using ocean forecasting for navigation?
# How can I access coastal services for safe navigation?
# What kind of data is available for ocean state forecasting?
# How can I use Copernicus Marine Service for coastal zone management?
# What are the latest developments in ocean forecasting technology?
#
#
# Topic id: 399
# Topic keywords: owairs, estonian, oceaangolf, waardeketen, finnish, search, swedish, danish, en, ondes
# Topic: Ocean-Atmosphere Interactions
# What is the main goal of the OWAIRS project?
# How does OWAIRS improve ocean-atmosphere interaction in regional seas?
# What are the benefits of OWAIRS for ocean forecasting?
# How does OWAIRS research impact our understanding of ocean-atmosphere interactions?
# What is the focus of the OWAIRS project in terms of ocean, wave, and atmosphere interactions?
#
#
# Topic id: 400
# Topic keywords: renumerate, renumerar, renumēt, renumerata, renumerat, renumereren, renumerado, renumerointi, renumerovať, renumerer
# Topic: Ocean Modeling and Tidal Forcing
# What is the purpose of the RENUMERATE project?
# How does RENUMERATE aim to improve ocean model simulations?
# What is the effect of explicit tidal forcing on numerical mixing in ocean models?
# How can the "z-tilde" modification reduce numerical mixing in ocean models?
# What are the potential benefits of adding explicit tidal currents to ocean models?
#
#
# Topic id: 401
# Topic keywords: sentinel, satellite, copernicus, radio, cookies, estonian, slovenian, lithuanian, français, latvian
# Topic: Copernicus Website
# What languages are available on the Copernicus website?
# What is the Sentinel-1A satellite used for?
# Can I change the language on the Copernicus website?
# What is the purpose of the radio frequency tests on Sentinel-1A?
# How do I save my language preferences on the Copernicus website?
#
#
# Topic id: 402
# Topic keywords: sentinel, satellite, esa, guiana, volcano, kourou, monitor, eruption, indonesia, laki
# Topic: Environmental Monitoring by Satellites
# What is the purpose of the Sentinel-1A satellite?
# How do satellites help monitor volcanic eruptions?
# What is the role of the ESA in environmental monitoring?
# Can satellites detect oil spills and track their movement?
# How do satellites assist in responding to natural disasters?
#
#
# Topic id: 403
# Topic keywords: multires, multi, search, cosi, português, liègeu, coastal, univerzita, aida, koncentracija
# Topic: Ocean Colour Satellite Products
# What is the purpose of the MultiRes project?
# How does the MultiRes project generate ocean colour satellite products?
# What is the spatial resolution of the ocean colour products generated by MultiRes?
# What technique is used to reconstruct missing data in the MultiRes project?
# What are the benefits of using multi-resolution ocean colour satellite products?
#
#
# Topic id: 404
# Topic keywords: vegetation, grassland, seasonal, metadata, dataset, raster, trajectories, 04, yearly, environments
# Topic: Vegetation Dataset
# What is the spatial resolution of the vegetation dataset?
# How often is the vegetation dataset updated?
# What type of sensor is used for the vegetation dataset?
# What is the temporal extent of the vegetation dataset?
# How can I download the vegetation dataset?
#
#
# Topic id: 405
# Topic keywords: medsub, csic, cmems, search, italiano, română, socib, main, massimili, submezoměřítkových
# Topic: MedSUB Ocean Monitoring
# What is MedSUB and what does it aim to achieve?
# How does MedSUB improve Mediterranean CMEMS products?
# What is the role of CSIC in the MedSUB project?
# What are the main goals of the MedSUB project in ocean monitoring?
# What is the significance of meso and submesoscale interactions in ocean monitoring?
#
#
# Topic id: 406
# Topic keywords: runoff, lambda, sss, watershed, river, salinity, timeseries, smos, salinité, system
# Topic: Salinity and River Runoff Data Analysis
# How can I compare satellite data with in situ data for river runoff?
# What is the salinity level in a specific watershed?
# How can I access timeseries data for river runoff?
# What tools are available for analyzing salinity data from SMOS?
# How can I visualize and compare different salinity products?
#
#
# Topic id: 407
# Topic keywords: 3da, scrum2, search, estonian, ocean, croatian, română, abstrakt, climsea, genoa
# Topic: Data Assimilation in Oceanic and Atmospheric Sciences
# What is data assimilation in oceanic and atmospheric sciences?
# How can data assimilation methods improve our understanding of geophysical dynamics?
# What is the analog data assimilation method and how does it work?
# How can historical data be used to improve forecasting in oceanic and atmospheric sciences?
# What are the benefits of using data-driven data assimilation in ocean monitoring?
#
#
# Topic id: 408
# Topic keywords: sentinel, volcano, eruption, esa, mount, launcher, laki, lithuanian, slovenian, monitor
# Topic: Volcanic Eruption Monitoring
# What is the Sentinel-5P satellite used for?
# How do volcanoes affect the environment?
# What is the role of the ESA in monitoring volcanic eruptions?
# Can satellites monitor volcanic activity?
# How does the Sentinel-5P satellite help in tracking eruptions?
#
#
# Topic id: 409
# Topic keywords: lmtl, cls, cmems, micronekton, search, estonian, climsea, funktionelle, scrum2, abstrakt
# Topic: Marine Ecosystem Management
# What are the benefits of using micronekton functional groups in ocean ecosystem management?
# How do mesozooplankton affect nutrient cycles and fish recruitment mechanisms?
# What are the key European maritime regions that will be covered by the LMTL model extension?
# How can LMTL products be used to assist in the conservation of endangered marine species?
# What is the purpose of the LMTL project in the context of CMEMS?
#
#
# Topic id: 410
# Topic keywords: 4dvarnet, estonian, oceandatalab, multires, français, croatian, latvian, search, hungarian, ofda
# Topic: Ocean Forecasting and Data Assimilation
# What is 4DVarNet-OFDA used for in ocean forecasting?
# How does 4DVarNet improve data assimilation in oceanography?
# What is the role of OceanDataLab in the 4DVarNet-OFDA project?
# What are the benefits of using 4DVarNet emulators in ocean forecasting?
# How does 4DVarNet-OFDA enhance Copernicus Marine Service products?
#
#
# Topic id: 411
# Topic keywords: fisheries, fish, habitat, marine, projekciju, stebėsenoje, zvejniecības, zvejniecībā, lähenemisviisi, pieeju
# Topic: Fisheries Management
# How can marine data support fisheries management?
# What is the role of essential fish habitat in fisheries policy?
# How can ecosystem approach help in managing fisheries?
# What data is used to implement the Common Fisheries Policy?
# How can marine monitoring support sustainable fishing?
#
#
# Topic id: 412
# Topic keywords: wambor, estonian, magellium, search, gilles, cnr, slovenian, coastal, français, croatian
# Topic: WAMBOR Ocean Monitoring Project
# What is the WAMBOR project about?
# What is the main goal of the WAMBOR project in ocean monitoring?
# How does the WAMBOR project use geodetic measurements?
# What is the role of Magellium in the WAMBOR project?
# What kind of data does the WAMBOR project analyze?
#
#
# Topic id: 413
# Topic keywords: fisheries, fishery, aquaculture, fish, fishermen, fishing, oceanography, map2fish, skyfish, sea
# Topic: Fisheries Management
# How can technology improve fisheries management?
# What tools are available for monitoring water quality in aquaculture?
# How can fishermen locate the closest legal fishing grounds?
# What initiatives support sustainable fishing practices?
# How can data from oceanography exploration tools be used in fisheries management?
#
#
# Topic id: 414
# Topic keywords: bioptimod, bio, biogeoquímicos, biomasa, cmems, biooptický, med, biomassa, scrum2, platforme
# Topic: Biogeochemical Modeling
# What is the main goal of the BIOPTIMOD project?
# How does the BIOPTIMOD project aim to improve biogeochemical products?
# What kind of data will be used to develop the multi-spectral bio-optical model?
# What is the role of optical observations in improving the quality of biogeochemical products?
# How will the new bio-optical model be integrated with existing biogeochemical models?
#
#
# Topic id: 415
# Topic keywords: plasticvervuiling, plastics, microplastics, plastic, debris, macroplastics, seawater, oppervlakte, oceaanoppervlak, oceanen
# Topic: Plasticvervuiling in de oceanen
# Hoe kan ik plasticvervuiling in mijn dagelijks leven verminderen?
# Wat zijn de belangrijkste oorzaken van plasticvervuiling in de oceanen?
# Hoe kan technologie helpen bij het bestrijden van plasticvervuiling?
# Wat is de invloed van slecht afvalbeheer op plasticvervuiling in de oceanen?
# Kan satellietcontrole worden gebruikt om plasticvervuiling in de oceanen te detecteren?
#
#
# Topic id: 416
# Topic keywords: optima, optische, search, cmems, ópticos, estonian, sistema, optical, pml, croatian
# Topic: Optical Data Modelling and Assimilation
# What is the main goal of the OPTIMA project?
# How does OPTIMA improve ocean monitoring?
# What is the role of PML in the OPTIMA project?
# What kind of data does OPTIMA assimilate into its ecosystem model?
# How does OPTIMA advance the capacity of CMEMS?
#
#
# Topic id: 417
# Topic keywords: copernicus, 2024, marine, oceans, 2028, sentinels, coastal, mercator, 2021, ecosystems
# Topic: Copernicus Marine Service
# How can marine data support coastal management?
# What are the benefits of using Copernicus Marine Service for ocean conservation?
# How does the Copernicus Marine Service contribute to maritime safety?
# What are the goals of the Copernicus Marine National Collaboration Programme?
# How can the Copernicus Marine Service help protect marine ecosystems?
#
#
# Topic id: 418
# Topic keywords: genoa, italiano, oċeani, oceanice, search, en, oceana, climsea, aspektem, scrum2
# Topic: Ocean Data Assimilation
# What is the main goal of the GENOA project in ocean data assimilation?
# How do ocean analysis systems currently handle ocean observations?
# What is the benefit of combining perturbation techniques with an ensemble approach in ocean data assimilation?
# How can the GENOA project improve the estimation of upper ocean properties?
# What is the expected outcome of applying the GENOA method to an ocean-atmosphere coupled system?
#
#
# Topic id: 419
# Topic keywords: climsea, search, scrum2, báltico, estonian, genoa, regionale, croatian, globale, klimato
# Topic: Climate Change Impact on Regional Seas
# What are the effects of climate change on regional seas?
# How does climate change impact marine ecosystems?
# What is the purpose of the CLIMSEA project?
# How can climate projections be downscaled for regional seas?
# What are the challenges facing the oceans due to global climate change?
#
#
# Topic id: 420
# Topic keywords: search, oceanográficos, dimup, ocean, datasynergier, skip, diagnosticar, page, main, estonian
# Topic: Ocean Data and Monitoring
# What is ocean monitoring and how does it work?
# How can I learn more about ocean data and its applications?
# What are the benefits of dynamic exploration in ocean research?
# How can I access ocean monitoring indicators and data?
# What is the purpose of the DIMUP project in ocean research?
#
#
# Topic id: 421
# Topic keywords: multicast, multires, multi, croatian, estonian, swedish, search, finnish, lithuanian, slovenian
# Topic: Ocean Forecasting
# What is the purpose of the MULTICAST project in ocean forecasting?
# How does the MULTICAST project improve regional ocean uncertainty modeling?
# What is the role of stochastic modeling in the MULTICAST project?
# What are the benefits of using multigrid configurations in ocean forecasting?
# How does the MULTICAST project support the evolution of high-resolution forecasting performance?
#
#
# Topic id: 422
# Topic keywords: sealevel_eur_phy_l3_nrt_008_059, sealevel_glo_phy_l3_nrt_008_044, sealevel_glo_phy_climate_l4_my_008_057, sealevel_glo_phy_l4_nrt_008_046, l3, l4, altimeter, l2, geophysical, nrt
# Topic: Sea Level Data Updates
# What is the impact of the new MDT on L3 and L4 products?
# How do altimeter standards and geophysical corrections affect sea level data?
# What changes can be expected in LWE correction computation?
# How will the new L4 CLIMATE GLO series improve sea level data?
# What are the benefits of reprocessing L2 data with new altimeter standards?
#
#
# Topic id: 423
# Topic keywords: glophyts, fitoplankton, fitoplanktona, glofiti, coastal, globales, globale, glofitos, globali, estonian
# Topic: Phytoplankton Monitoring
# What is the purpose of the GLOPHYTS project?
# How does the GLOPHYTS project monitor phytoplankton function types?
# What data does the GLOPHYTS project provide on the EU Copernicus Marine Service?
# How long has the GLOPHYTS project been collecting data on phytoplankton function types?
# What is the goal of merging PFT data sets from different sensors in the GLOPHYTS project?
#
#
# Topic id: 424
# Topic keywords: copernicusems, cookies, analytics, gdpr, maps, privacy, emsr325, map, emergency, server
# Topic: Copernicus EMS Data and Privacy
# What is the purpose of cookies on the Copernicus website?
# How does Copernicus EMS use analytics for internal research?
# What kind of data does Copernicus EMS collect through cookies?
# How does Copernicus EMS ensure user data protection under GDPR?
# What is the role of Matomo analytics in enhancing Copernicus EMS services?
#
#
# Topic id: 425
# Topic keywords: temperatures, septembers, september, temperature, warmest, warmer, 2023, antarctic, october, antarctica
# Topic: Global Temperatures
# What was the global temperature in September 2023?
# Was September 2024 the warmest September on record?
# How did the global temperature in September 2024 compare to the previous year?
# What was the average temperature over European land in September 2024?
# Was 2023 the warmest year on record?

# %%
import json
with open("datasets/Copernicus.json", "w") as f:
    json.dump(dataset, f)
